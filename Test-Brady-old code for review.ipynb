# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ### Datasets:
#
# Here's one dataset for food prices https://www.kaggle.com/jboysen/global-food-prices
#
# Here is the dataset for temperature and rainfalls http://sdwebx.worldbank.org/climateportal/index.cfm?page=downscaled_data_download&menu=historical

# %% [markdown]
# ### Hypothesis:
#
# Do changes in average temperature and average level of rainfall affect the change in the average price on X crop in X country in X-X years

# %% [markdown]
# ### Questions to the Professor:
#
# 1. How can we all access and work simultaneously in the shared Github repo (with 1 master and 3 collaborators)?

# %%
import pandas as pd

pricesdata='https://raw.githubusercontent.com/vzakhozhyi/599-A-Final-Project/master/Data/wfp_market_food_prices.csv'
prices = pd.read_csv(pricesdata,header=0, encoding = 'ISO-8859-1')

#Bolivia
TBdata="https://github.com/vzakhozhyi/599-A-Final-Project/raw/master/Data/Temp_Bolivia.xls"
TB=pd.read_excel(TBdata)

RFBdata="https://github.com/vzakhozhyi/599-A-Final-Project/raw/master/Data/Rainfall_Bolivia.xls"
RFB=pd.read_excel(RFBdata)

#Peru
TPdata="https://github.com/vzakhozhyi/599-A-Final-Project/raw/master/Data/Temp_Peru.xls"
TP=pd.read_excel(TPdata)

RFPdata="https://github.com/vzakhozhyi/599-A-Final-Project/raw/master/Data/Rainfall_Peru.xls"
RFP=pd.read_excel(RFPdata)

#Colombia
TCdata="https://github.com/vzakhozhyi/599-A-Final-Project/raw/master/Data/Temp_Colombia.xls"
TC=pd.read_excel(TCdata)

RFCdata="https://github.com/vzakhozhyi/599-A-Final-Project/raw/master/Data/Rainfall_Colombia.xls"
RFC=pd.read_excel(RFCdata)

# %%
TB.shape
# Out:
# (300, 6)

# %%
Tdataframes = [TB, TC, TP]

Temp = pd.concat(Tdataframes)
Temp
# Out:
#          tas  \tYear   Month  Country   ISO3   ISO2
# 0    23.3426    1991       1      BOL    NaN    NaN
# 1    23.1225    1991       2      BOL    NaN    NaN
# 2    22.4283    1991       3      BOL    NaN    NaN
# 3    21.2055    1991       4      BOL    NaN    NaN
# 4    19.9238    1991       5      BOL    NaN    NaN
# 5    18.2097    1991       6      BOL    NaN    NaN
# 6    17.7880    1991       7      BOL    NaN    NaN
# 7    19.2964    1991       8      BOL    NaN    NaN
# 8    21.4351    1991       9      BOL    NaN    NaN
# 9    22.0184    1991      10      BOL    NaN    NaN
# 10   22.5688    1991      11      BOL    NaN    NaN
# 11   23.1559    1991      12      BOL    NaN    NaN
# 12   22.1763    1992       1      BOL    NaN    NaN
# 13   22.3409    1992       2      BOL    NaN    NaN
# 14   21.6967    1992       3      BOL    NaN    NaN
# 15   20.9250    1992       4      BOL    NaN    NaN
# 16   20.4805    1992       5      BOL    NaN    NaN
# ...

# %%
Tclean=Temp.drop(columns=[' ISO3', ' ISO2'])

# %%
Tclean.shape
# Out:
# (900, 4)

# %%
Tnewnames=['temperature', 'year', ' month', 'country']
Tnew={old:new for old,new in zip(Tclean,Tnewnames)}
Tclean.rename(columns=Tnew,inplace=True)
Tclean
# Out:
#      temperature  year   month country
# 0        23.3426  1991       1     BOL
# 1        23.1225  1991       2     BOL
# 2        22.4283  1991       3     BOL
# 3        21.2055  1991       4     BOL
# 4        19.9238  1991       5     BOL
# 5        18.2097  1991       6     BOL
# 6        17.7880  1991       7     BOL
# 7        19.2964  1991       8     BOL
# 8        21.4351  1991       9     BOL
# 9        22.0184  1991      10     BOL
# 10       22.5688  1991      11     BOL
# 11       23.1559  1991      12     BOL
# 12       22.1763  1992       1     BOL
# 13       22.3409  1992       2     BOL
# 14       21.6967  1992       3     BOL
# 15       20.9250  1992       4     BOL
# 16       20.4805  1992       5     BOL
# 17       18.7640  1992       6     BOL
# 18       16.4989  1992       7     BOL
# 19       18.4649  1992       8     BOL
# 20       20.1317  1992       9     BOL
# 21       21.9969  1992      10     BOL
# 22       21.9721  1992      11     BOL
# ...

# %%
Tclean['country']=Tclean['country'].replace(['PER'], 'Peru')
Tclean['country']=Tclean['country'].replace(['COL'], 'Columbia')
Tclean['country']=Tclean['country'].replace(['BOL'], 'Bolivia')
#Price['cm_name'] = pd.Price['cm_name'].replace(['Potatoes (Dutch)'], 'Potatoes')

# %%
years=['2008','2009','2010','2011','2012','2013','2014','2015']
Tclean = Tclean[Tclean.year.isin(years)]
Tclean
# Out:
#      temperature  year   month  country
# 204      21.8398  2008       1  Bolivia
# 205      21.8494  2008       2  Bolivia
# 206      21.3462  2008       3  Bolivia
# 207      19.8720  2008       4  Bolivia
# 208      17.5124  2008       5  Bolivia
# 209      16.1819  2008       6  Bolivia
# 210      18.5013  2008       7  Bolivia
# 211      19.5740  2008       8  Bolivia
# 212      20.1788  2008       9  Bolivia
# 213      23.7426  2008      10  Bolivia
# 214      23.7620  2008      11  Bolivia
# 215      23.0890  2008      12  Bolivia
# 216      21.9304  2009       1  Bolivia
# 217      22.9417  2009       2  Bolivia
# 218      22.7067  2009       3  Bolivia
# 219      20.9677  2009       4  Bolivia
# 220      19.3103  2009       5  Bolivia
# 221      16.7260  2009       6  Bolivia
# 222      17.5008  2009       7  Bolivia
# 223      19.1220  2009       8  Bolivia
# 224      20.5798  2009       9  Bolivia
# 225      22.4539  2009      10  Bolivia
# ...
