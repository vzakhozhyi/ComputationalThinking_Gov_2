# %% [markdown]
# <center><img src="http://i.imgur.com/sSaOozN.png" width="500"></center>

# %% [markdown]
# ## Course: Computational Thinking for Governance Analytics
#
# ### Prof. José Manuel Magallanes, PhD
# * Visiting Professor of Computational Policy at Evans School of Public Policy and Governance, and eScience Institute Senior Data Science Fellow, University of Washington.
# * Professor of Government and Political Methodology, Pontificia Universidad Católica del Perú.
#
# _____
#
# # Session 2:  Data Preprocessing in Python

# %% [markdown]
# <a id='beginning'></a>
#
# Preprocessing includes three stages:
#
# 1. [Collecting](#part1)
# 2. [Cleaning](#part2)
# 3. [Formatting](#part3)

# %% [markdown]
# ____
# <a id='part1'></a>
#
# ## Collecting

# %% [markdown]
# Collection is not a pre processing problem if you have data already nicely organized. When it is so, **pandas** will read the file without problem:
#
# * Reading STATA file

# %%
import pandas as pd

stataFile='https://github.com/EvansDataScience/data/raw/master/lapopUSA2017_13.dta'
##
dataStata=pd.read_stata(stataFile,convert_categoricals=False)

# %% [markdown]
# * Reading EXCEL file

# %%
excelFile='https://github.com/EvansDataScience/data/raw/master/hdi2016.xlsx'
dataExcel=pd.read_excel(excelFile)

# %% [markdown]
# As you just have seen, a common file type can be easily read using pandas. Once you have them, you can ask many things, some could be:
#
# * Number of rows and columns:

# %%
dataStata.shape
# Out:
# (1500, 119)

# %% [markdown]
# * See the first rows:

# %%
dataExcel.head()
# Out:
#        Country  Human Development Index (HDI)   Life expectancy at birth  \
# 0       Norway                        0.949423                    81.711
# 1    Australia                        0.938680                    82.537
# 2  Switzerland                        0.939131                    83.133
# 3      Germany                        0.925669                    81.092
# 4      Denmark                        0.924649                    80.412
#
#    Expected years of schooling   Mean years of schooling  \
# 0                      17.67187                12.746420
# 1                      20.43272                13.175100
# 2                      16.04041                13.370000
# 3                      17.09594                13.187626
# 4                      19.18880                12.700170
#
#    Gross national income (GNI) per capita                     Category
# 0                             67614.35348  VERY HIGH HUMAN DEVELOPMENT
# 1                             42822.19627  VERY HIGH HUMAN DEVELOPMENT
# 2                             56363.95780  VERY HIGH HUMAN DEVELOPMENT
# 3                             44999.64714  VERY HIGH HUMAN DEVELOPMENT
# 4                             44518.92402  VERY HIGH HUMAN DEVELOPMENT

# %% [markdown]
# The property __shape__ is an attribute of the data frame, so you do not need parentheses; you do not these ones to call a function, in this last case __head()__. You also have __tail()__:

# %%
dataStata[['q12','q12m','q12f']].tail()
# Out:
#       q12  q12m  q12f
# 1495  2.0   1.0   1.0
# 1496  0.0   NaN   NaN
# 1497  0.0   NaN   NaN
# 1498  0.0   NaN   NaN
# 1499  1.0   1.0   0.0

# %% [markdown]
# The tail is showing only the last elements of the selected columns.
#
# * Self-collecting
#
# Another way to collect data is to create an online form and then get the data into Python. For this situation, go to this [link](https://goo.gl/forms/HX3KkxcEtXgMzyDJ3) and answer the questions.
#
# Then, I will see the answers:

# %%
link='https://docs.google.com/spreadsheets/d/e/2PACX-1vT9zoGqRmUztGnDgjD4zWTQlttDyO5uRTotZQNQM_aUMrwhfOTf_0mpASz3Cra65VYF6DeCVxCm77Mj/pub?gid=1005402639&single=true&output=csv'
namesOfCols=['timeStamp','name','sex','age','bornIn','workingStatus']

myData = pd.read_csv(link,header=0,names=namesOfCols) #header = 0 means header is the first line

# here it is:
myData.head(10)
# Out:
#             timeStamp                    name       sex    age bornIn  \
# 0   1/30/2019 9:35:58                     Nat       Man   29.0     CA
# 1    2/4/2019 8:52:09              Ian Langer       Man   27.0     NC
# 2   2/4/2019 11:35:41                   Jenny     Woman   28.0     NM
# 3   2/5/2019 19:29:26      Bradocius the Wise  An ideal  111.0     WA
# 4   2/9/2019 19:33:48  Jose Luis Gomez-Angulo       Man   26.0     AZ
# 5   2/9/2019 19:34:41  Jose Luis Gomez-Angulo       Man   26.0     AZ
# 6   2/9/2019 19:35:42  Jose Luis Gomez-Angulo       Man   26.0     AZ
# 7  2/11/2019 13:15:18                     Ana     Woman   26.0     GE
# 8  2/11/2019 13:17:18                     Ana     Woman   26.0     Ge
# 9  2/11/2019 16:24:11          Todd Albertson       Man   25.0     CA
#
#           workingStatus
# 0    Intern with salary
# 1    Intern with salary
# 2  Employed with salary
# 3    Intern with salary
# 4           Not working
# 5           Not working
# 6           Not working
# 7           Not working
# 8           Not working
# 9           Not working

# %% [markdown]
# The information collected was retrieved in a comma-separated values format. This is a very common format. Notice the settings of __read_csv__: I tell pandas that the first row has the names of the columns (header is in position 0); and then I rename the headers.

# %% [markdown]
# * Collecting data from APIs
#
# Most of these data come in more complex formats, like XML or JSON format. Let's get the data about
# [Seattle Real Time Fire 911 Calls](https://dev.socrata.com/foundry/data.seattle.gov/grwu-wqtk). Let me follow the instructions from that website to get the data:

# %%
# !pip install sodapy # pip install sodapy
# Out:
# Collecting sodapy
#   Downloading https://files.pythonhosted.org/packages/11/02/5baf6e10a47018babcc43e3ed03a6f13712187f4ab1fbe263b479c77d117/sodapy-1.5.2-py2.py3-none-any.whl
# Requirement already satisfied: future>=0.17.1 in /anaconda3/lib/python3.7/site-packages (from sodapy) (0.17.1)
# Requirement already satisfied: requests>=2.20.0 in /anaconda3/lib/python3.7/site-packages (from sodapy) (2.21.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (2018.11.29)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (3.0.4)
# Installing collected packages: sodapy
# Successfully installed sodapy-1.5.2

# %%
from sodapy import Socrata

client = Socrata("data.seattle.gov", None)
results = client.get("grwu-wqtk", limit=1000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   :@computed_region_2day_rhn5 :@computed_region_cyqu_gs94  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   :@computed_region_kuhn_3gp2 :@computed_region_q256_3sug  \
# 0                          29                       19579
# 1                          41                       17919
# 2                          44                       18388
# 3                          22                       18379
# 4                          34                       18377
#
#                       address                 datetime incident_number  \
# 0            11528 28th Av Ne  2011-03-09T01:11:00.000      F110020765
# 1              3732 14th Av S  2017-12-10T03:10:00.000      F170128702
# 2     Beacon Av S / S Eddy St  2017-05-03T00:11:00.000      F170042740
# 3  4th Av S / S Washington St  2017-04-11T06:41:00.000      F170035060
# 4            8830 Nesbit Av N  2012-02-07T18:31:00.000      F120011815
#
#     latitude    longitude                                    report_location  \
# 0    47.7123  -122.297578  {'type': 'Point', 'coordinates': [-122.297578,...
# 1  47.570516  -122.314759  {'type': 'Point', 'coordinates': [-122.314759,...
# 2  47.545329   -122.30029  {'type': 'Point', 'coordinates': [-122.30029, ...
# 3  47.600875  -122.328963  {'type': 'Point', 'coordinates': [-122.328963,...
# 4  47.692638  -122.343471  {'type': 'Point', 'coordinates': [-122.343471,...
#
#                            type
# 0                Medic Response
# 1                  Aid Response
# 2  MVI - Motor Vehicle Incident
# 3                  Aid Response
# 4    Medic Response- 6 per Rule

# %% [markdown]
# [Go to page beginning](#beginning)

# %% [markdown]
# _____
# <a id='part2'></a>
#
# ## Cleaning

# %% [markdown]
# The files opened above look clean because they may have been produce professionally for statistical work, or because the collecting tool was very restrictive. However, several data that you collect may not bring you the data as clean as the ones found in the previous codes. This commmon webpage has a table that may be needed:

# %%
wikiLink="https://en.wikipedia.org/wiki/List_of_freedom_indices"


import IPython
iframe = '<iframe src=' + wikiLink + ' width=700 height=350></iframe>'
IPython.display.HTML(iframe)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=https://en.wikipedia.org/wiki/List_of_freedom_indices width=700 height=350></iframe>

# %% [markdown]
# Let's try to get the table using pandas:

# %%
import pandas as pd

#attrs - what html attributes i am looking for (class & wikitable sortable are html definitions)

wikiTables=pd.read_html(wikiLink,header=0,attrs={'class': 'wikitable sortable'})

# %% [markdown]
# I tried to get all the tables. I may have more than one:

# %%
# What do I have? / How many?
type(wikiTables), len(wikiTables)

#pandas gives a collecion of wikitables, can be more than 1, and it is shown as list with 1 wikitable element
# Out:
# (list, 1)

# %% [markdown]
# I need to recover the first table from the list (the only one).

# %%
DF=wikiTables[0]

#what is it?
type(DF)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Great!...we have a data frame; then:

# %%
DF.head()
# Out:
#        Country  Freedom in the World 2018[10]  \
# 0     Abkhazia                            NaN
# 1  Afghanistan                            NaN
# 2      Albania                            NaN
# 3      Algeria                            NaN
# 4      Andorra                            NaN
#
#    2018 Index of Economic Freedom[11]  2018 Press Freedom Index[3]  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
#
#    2017 Democracy Index[13]
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %% [markdown]
# This data frame does not look like the one we see on the website. We need to improve the call:

# %%
# install 'beautifulsoup4'
DF=pd.read_html(wikiLink,header=0,flavor='bs4',attrs={'class': 'wikitable sortable'})[0]
DF.head()

#flavor parameter tells us that panda will not use its own algorythms to scrape text, but the algorythms of "beautifulsoup4" package. To install package manually, use !pip install bs4

#NaN is a good way of showing missing value
# Out:
#        Country Freedom in the World 2018[10]  \
# 0     Abkhazia                   partly free
# 1  Afghanistan                      not free
# 2      Albania                   partly free
# 3      Algeria                      not free
# 4      Andorra                          free
#
#   2018 Index of Economic Freedom[11] 2018 Press Freedom Index[3]  \
# 0                                NaN                         NaN
# 1                      mostly unfree         difficult situation
# 2                    moderately free         noticeable problems
# 3                          repressed         difficult situation
# 4                                NaN      satisfactory situation
#
#   2017 Democracy Index[13]
# 0                      NaN
# 1     authoritarian regime
# 2            hybrid regime
# 3     authoritarian regime
# 4                      NaN

# %% [markdown]
# Combining BeautifulSoup (BS) and Pandas gave us the right result. But our work is not over.
#
# Pay attention to the cleaning pandas+BS have done: the 'n/a' was interpreted as **NaN**; no country flags in the data; and the headers are in the right place.
#
# However, to prepare a final data set, we should pay attention to the headers names to avoid _blanks_, and erase the _footnote_ call.
#
# We can have two strategies:
# * Brute-force!

# %%
# if we had a small number of names to change, we can use brute-force strategy (writing the list of columns names):
DF.columns=['Country',
 'FreedomintheWorld',
 'IndexofEconomicFreedom',
 'PressFreedomIndex',
 'DemocracyIndex']
DF.head()
# Out:
#        Country FreedomintheWorld IndexofEconomicFreedom  \
# 0     Abkhazia       partly free                    NaN
# 1  Afghanistan          not free          mostly unfree
# 2      Albania       partly free        moderately free
# 3      Algeria          not free              repressed
# 4      Andorra              free                    NaN
#
#         PressFreedomIndex        DemocracyIndex
# 0                     NaN                   NaN
# 1     difficult situation  authoritarian regime
# 2     noticeable problems         hybrid regime
# 3     difficult situation  authoritarian regime
# 4  satisfactory situation                   NaN

# %% [markdown]
# * Using more computational thinking (algorithmic):

# %%
# if we had many columns, writing an algorith to rename the columns could be better:

# recalling the data:
DF=pd.read_html(wikiLink,header=0,flavor='bs4',attrs={'class': 'wikitable sortable'})[0]

# %% [markdown]
# I just recalled the data to do several steps:
#
# 1. Find blanks.
# 2. Find numbers.
# 3. Find brackets (opening and closing).
#
# The previous requires a **regular expresssion**:

# %%
import re  # may need to be installed:

# find blanks: \\s+
# find numbers: \\d+ 
# find opening bracket : \\[
# find closing bracket: \\]

# You can combine using '|' (or):
pattern='\\s+|\\d+|\\[|\\]'
nothing=''

# %% [markdown]
# Now, let's see how this works for one case:

# %%
testString='Freedom in the World 2018[10]'
re.sub(pattern,nothing,testString) #re.sub - is a function of re package to substitute
# Out:
# 'FreedomintheWorld'

# %% [markdown]
# Now, let's see how this works for ALL cases:

# %%
DF.columns
# Out:
# Index(['Country', 'Freedom in the World 2018[10]',
#        '2018 Index of Economic Freedom[11]', '2018 Press Freedom Index[3]',
#        '2017 Democracy Index[13]'],
#       dtype='object')

# %%
#using comprehension

[re.sub(pattern,nothing,name) for name in DF.columns]
# Out:
# ['Country',
#  'FreedomintheWorld',
#  'IndexofEconomicFreedom',
#  'PressFreedomIndex',
#  'DemocracyIndex']

# %% [markdown]
# We can verify we are matching well:

# %%
newNames=[re.sub(pattern,nothing,name) for name in DF.columns]

# checking:
list(zip(DF.columns,newNames))
# Out:
# [('Country', 'Country'),
#  ('Freedom in the World 2018[10]', 'FreedomintheWorld'),
#  ('2018 Index of Economic Freedom[11]', 'IndexofEconomicFreedom'),
#  ('2018 Press Freedom Index[3]', 'PressFreedomIndex'),
#  ('2017 Democracy Index[13]', 'DemocracyIndex')]

# %% [markdown]
# Let's turn that match into a dictionary:

# %%
{old:new for old,new in zip(DF.columns,newNames)}
# Out:
# {'Country': 'Country',
#  'Freedom in the World 2018[10]': 'FreedomintheWorld',
#  '2018 Index of Economic Freedom[11]': 'IndexofEconomicFreedom',
#  '2018 Press Freedom Index[3]': 'PressFreedomIndex',
#  '2017 Democracy Index[13]': 'DemocracyIndex'}

# %% [markdown]
# Once you have a dict like that one, you can use it to rename the columns with another function:

# %%
changes={old:new for old,new in zip(DF.columns,newNames)}
DF.rename(columns=changes,inplace=True) #inplace - do this thing and change it immediately in the dataframe

# %% [markdown]
# If you had a set of new names, and you do not want to change every column name, that is the correct way to do it.
#
# Let's see the result:

# %%
DF.head()
# Out:
#        Country FreedomintheWorld IndexofEconomicFreedom  \
# 0     Abkhazia       partly free                    NaN
# 1  Afghanistan          not free          mostly unfree
# 2      Albania       partly free        moderately free
# 3      Algeria          not free              repressed
# 4      Andorra              free                    NaN
#
#         PressFreedomIndex        DemocracyIndex
# 0                     NaN                   NaN
# 1     difficult situation  authoritarian regime
# 2     noticeable problems         hybrid regime
# 3     difficult situation  authoritarian regime
# 4  satisfactory situation                   NaN

# %% [markdown]
# A next step will be verifying if the answers are well coded:

# %%
DF.iloc[:,1::].describe() #no need to check Country column as they are unique
# Out:
#        FreedomintheWorld IndexofEconomicFreedom    PressFreedomIndex  \
# count                206                    180                  189
# unique                 3                      5                    5
# top                 free          mostly unfree  noticeable problems
# freq                  89                     63                   63
#
#           DemocracyIndex
# count                167
# unique                 4
# top     flawed democracy
# freq                  57

# %% [markdown]
# What were you looking for?
# Sometimes a category may be wrongly written in a cell, for instance, if you had 'Free' and 'free' or 'free ' to represent the same in one column, you have a mistake. Let's see if there is one here:

# %%
DF.FreedomintheWorld.value_counts()
# Out:
# free           89
# partly free    62
# not free       55
# Name: FreedomintheWorld, dtype: int64

# %% [markdown]
#  What we see is that this variable has its own correct set of answers.
#
#  We can try that approach for each variable, but we can check the whole group of categorical values like thisL

# %%
# DF.iloc[:,1::] all columns but the first one
# apply(set)  apply the function 'set()'  per column # give unique values
# tolist() convert to a list 

DF.iloc[:,1::].apply(set).tolist()
# Out:
# [{'free', nan, 'not free', 'partly free'},
#  {'free', 'moderately free', 'mostly free', 'mostly unfree', nan, 'repressed'},
#  {'difficult situation',
#   'good situation',
#   nan,
#   'noticeable problems',
#   'satisfactory situation',
#   'very serious situation'},
#  {'authoritarian regime',
#   'flawed democracy',
#   'full democracy',
#   'hybrid regime',
#   nan}]

# %% [markdown]
# [Go to page beginning](#beginning)
# ____
# <a id='part3'></a>
# ## Formatting

# %% [markdown]
# The data seems _clean_, but we need now to be sure the information is in the right format. This varies according to the project; so, let me show you some steps during of the formatting stage.
#
# 1. Verify the data types:

# %%
DF.dtypes
# Out:
# Country                   object
# FreedomintheWorld         object
# IndexofEconomicFreedom    object
# PressFreedomIndex         object
# DemocracyIndex            object
# dtype: object

# %% [markdown]
# All but the first variable are categories, not text (_object_). To convert them into categories you can do this:

# %%
headerNames=DF.columns
DF[headerNames[1:]]=DF[headerNames[1:]].astype('category')

# %% [markdown]
# When a variable is of categorical type, you can use particular functions for them:

# %%
DF.FreedomintheWorld.cat.categories #doesnt show missing values, bcz its already a category
# Out:
# Index(['free', 'not free', 'partly free'], dtype='object')

# %%
DF.IndexofEconomicFreedom.cat.categories
# Out:
# Index(['free', 'moderately free', 'mostly free', 'mostly unfree', 'repressed'], dtype='object')

# %%
DF.PressFreedomIndex.cat.categories
# Out:
# Index(['difficult situation', 'good situation', 'noticeable problems',
#        'satisfactory situation', 'very serious situation'],
#       dtype='object')

# %%
DF.DemocracyIndex.cat.categories
# Out:
# Index(['authoritarian regime', 'flawed democracy', 'full democracy',
#        'hybrid regime'],
#       dtype='object')

# %% [markdown]
# 2. If ordinal, make the adjustment.

# %% [markdown]
# The order in which the categories differentiate a plain categorical from an ordinal categorical. They should be categorical but the order does not reflect the order it should.
#
# We can turn it into an ordinal doing the following:
#
# a. Find a good numeric sequence for the ordinal values:

# %%
# notice I am using the numbers in the same order as the list of categorical values:
oldFree=list(DF.FreedomintheWorld.cat.categories)

# '5 very good' / '4 good' / '3 middle' / '2 bad' / '1 very bad'

#mapping

newFree=[5,1,3]
recodeFree={old:new for old,new in zip (oldFree,newFree)}

oldEco=list(DF.IndexofEconomicFreedom.cat.categories)
newEco=[5,3,4,2,1]
recodeEco={old:new for old,new in zip (oldEco,newEco)}

oldPress=list(DF.PressFreedomIndex.cat.categories)
newPress=[2,5,3,4,1]
recodePress={old:new for old,new in zip (oldPress,newPress)}

oldDemo=list(DF.DemocracyIndex.cat.categories)
newDemo=[1,4,5,2]
recodeDemo={old:new for old,new in zip (oldDemo,newDemo)}

# %% [markdown]
# b. Rename the still plain categorical:

# %%
DF.FreedomintheWorld.cat.rename_categories(recodeFree,inplace=True)

DF.IndexofEconomicFreedom.cat.rename_categories(recodeEco,inplace=True)

DF.PressFreedomIndex.cat.rename_categories(recodePress,inplace=True)

DF.DemocracyIndex.cat.rename_categories(recodeDemo,inplace=True)

# veamos:
DF.head(10)
# Out:
#                Country FreedomintheWorld IndexofEconomicFreedom  \
# 0             Abkhazia                 3                    NaN
# 1          Afghanistan                 1                    2.0
# 2              Albania                 3                    3.0
# 3              Algeria                 1                    1.0
# 4              Andorra                 5                    NaN
# 5               Angola                 1                    1.0
# 6  Antigua and Barbuda                 5                    NaN
# 7            Argentina                 5                    2.0
# 8              Armenia                 3                    3.0
# 9            Australia                 5                    5.0
#
#   PressFreedomIndex DemocracyIndex
# 0               NaN            NaN
# 1               2.0            1.0
# 2               3.0            2.0
# 3               2.0            1.0
# 4               4.0            NaN
# 5               2.0            1.0
# 6               4.0            NaN
# 7               3.0            4.0
# 8               3.0            2.0
# 9               4.0            5.0

# %%
DF.dtypes
# Out:
# Country                     object
# FreedomintheWorld         category
# IndexofEconomicFreedom    category
# PressFreedomIndex         category
# DemocracyIndex            category
# dtype: object

# %% [markdown]
# c. Now turn the renamed columns into a numeric values:

# %%
DF[headerNames[1:]]=DF[headerNames[1:]].apply(pd.to_numeric)

# %% [markdown]
# Let me verify:

# %%
DF.head()
# Out:
#        Country  FreedomintheWorld  IndexofEconomicFreedom  PressFreedomIndex  \
# 0     Abkhazia                3.0                     NaN                NaN
# 1  Afghanistan                1.0                     2.0                2.0
# 2      Albania                3.0                     3.0                3.0
# 3      Algeria                1.0                     1.0                2.0
# 4      Andorra                5.0                     NaN                4.0
#
#    DemocracyIndex
# 0             NaN
# 1             1.0
# 2             2.0
# 3             1.0
# 4             NaN

# %% [markdown]
# 3. Try solving missing data presence
#
# The data has some missing data:

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 5 columns):
# Country                   207 non-null object
# FreedomintheWorld         206 non-null float64
# IndexofEconomicFreedom    180 non-null float64
# PressFreedomIndex         189 non-null float64
# DemocracyIndex            167 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 8.2+ KB

# %% [markdown]
# Now comes the thinking: How to replace the missing values?
#
# Python can easily find and replace every missing value; but our strategy will be different:
#
# * _Freedom in the World_ has the least missing values, we will use this variable to see how the others behave.
#
# * Since the variables are ordinals (even though they are numbers now) a good candidate to impute a missing is the median NOT the mean (you can not compute the mean of an ordinal).
#
# Let's see:

# %%
#median per group: 
DF.groupby('FreedomintheWorld')[headerNames[2:]].median()
# Out:
#                    IndexofEconomicFreedom  PressFreedomIndex  DemocracyIndex
# FreedomintheWorld
# 1.0                                   2.0                2.0             1.0
# 3.0                                   2.0                3.0             2.0
# 5.0                                   3.0                4.0             4.0

# %% [markdown]
# We need to replace those medians whenever a missing value is found:

# %%
for col in headerNames[2:]:
    # in each column, get median by FIW group, and use it to replace the missing values.
    DF[col].fillna(DF.groupby(["FreedomintheWorld"])[col].transform("median"), inplace=True)

# %%
DF.head(20)
# Out:
#                 Country  FreedomintheWorld  IndexofEconomicFreedom  \
# 0              Abkhazia                3.0                     2.0
# 1           Afghanistan                1.0                     2.0
# 2               Albania                3.0                     3.0
# 3               Algeria                1.0                     1.0
# 4               Andorra                5.0                     3.0
# 5                Angola                1.0                     1.0
# 6   Antigua and Barbuda                5.0                     3.0
# 7             Argentina                5.0                     2.0
# 8               Armenia                3.0                     3.0
# 9             Australia                5.0                     5.0
# 10              Austria                5.0                     4.0
# 11           Azerbaijan                1.0                     3.0
# 12              Bahamas                5.0                     3.0
# 13              Bahrain                1.0                     3.0
# 14           Bangladesh                3.0                     2.0
# 15             Barbados                5.0                     2.0
# 16              Belarus                1.0                     2.0
# 17              Belgium                5.0                     3.0
# 18               Belize                5.0                     2.0
# 19                Benin                5.0                     2.0
#
#     PressFreedomIndex  DemocracyIndex
# 0                 3.0             2.0
# 1                 2.0             1.0
# 2                 3.0             2.0
# 3                 2.0             1.0
# 4                 4.0             4.0
# 5                 2.0             1.0
# 6                 4.0             4.0
# 7                 3.0             4.0
# 8                 3.0             2.0
# 9                 4.0             5.0
# 10                5.0             5.0
# 11                1.0             1.0
# 12                4.0             4.0
# 13                1.0             1.0
# 14                2.0             2.0
# 15                4.0             4.0
# 16                2.0             1.0
# 17                5.0             4.0
# 18                4.0             4.0
# 19                3.0             2.0

# %% [markdown]
# We can send this to R, in a simple CSV format:

# %%
DF.to_csv("indexes.csv",index=None)

# %% [markdown]
# ______
#
# ## More examples
#
# ### Case: Democracy Index

# %% [markdown]
# Let me clean a similar data from wikipedia, about democracy index:

# %%
import pandas as pd #location:
demoLink = "https://en.wikipedia.org/wiki/Democracy_Index" 

#collection
demodex=pd.read_html(demoLink,header=0,flavor='bs4',attrs={'class': 'wikitable sortable'})[0]

# %% [markdown]
# 1. Looking for messiness:

# %%
# what's on top?
# names? weird symbols? more links?
demodex.head(10)
# Out:
#   Rank      Country Score Electoral processand pluralism  \
# 0    1       Norway  9.87                          10.00
# 1    2      Iceland  9.58                          10.00
# 2    3       Sweden  9.39                           9.58
# 3    4  New Zealand  9.26                          10.00
# 4    5      Denmark  9.22                          10.00
# 5   =6      Ireland  9.15                           9.58
# 6   =6       Canada  9.15                           9.58
# 7    8      Finland  9.14                          10.00
# 8    9    Australia  9.09                          10.00
# 9   10  Switzerland  9.03                           9.58
#
#   Functioning ofgovernment Politicalparticipation Politicalculture  \
# 0                     9.64                  10.00            10.00
# 1                     9.29                   8.89            10.00
# 2                     9.64                   8.33            10.00
# 3                     9.29                   8.89             8.13
# 4                     9.29                   8.33             9.38
# 5                     7.86                   8.33            10.00
# 6                     9.64                   7.78             8.75
# 7                     8.93                   8.33             8.75
# 8                     8.93                   7.78             8.75
# 9                     9.29                   7.78             9.38
#
#   Civilliberties        Category
# 0           9.71  Full democracy
# 1           9.71  Full democracy
# 2           9.41  Full democracy
# 3          10.00  Full democracy
# 4           9.12  Full democracy
# 5          10.00  Full democracy
# 6          10.00  Full democracy
# 7           9.71  Full democracy
# 8          10.00  Full democracy
# 9           9.12  Full democracy

# %%
# what's at the bottom?
# note? credits? extra info?

demodex.tail(10)
# Out:
#      Rank                           Country  Score  \
# 158  =159                      Saudi Arabia   1.93
# 159  =159                        Tajikistan   1.93
# 160   161                 Equatorial Guinea   1.92
# 161   162                      Turkmenistan   1.72
# 162   163                              Chad   1.61
# 163   164          Central African Republic   1.52
# 164   165  Democratic Republic of the Congo   1.49
# 165   166                             Syria   1.43
# 166   167                       North Korea   1.08
# 167  Rank                           Country  Score
#
#      Electoral processand pluralism  Functioning ofgovernment  \
# 158                            0.00                      2.86
# 159                            0.08                      0.79
# 160                            0.00                      0.43
# 161                            0.00                      0.79
# 162                            0.00                      0.00
# 163                            2.25                      0.00
# 164                            0.50                      0.71
# 165                            0.00                      0.00
# 166                            0.00                      2.50
# 167  Electoral processand pluralism  Functioning ofgovernment
#
#      Politicalparticipation  Politicalculture  Civilliberties       Category
# 158                    2.22              3.13            1.47  Authoritarian
# 159                    1.67              6.25            0.88  Authoritarian
# 160                    3.33              4.38            1.47  Authoritarian
# 161                    2.22              5.00            0.59  Authoritarian
# 162                    1.67              3.75            2.65  Authoritarian
# 163                    1.11              1.88            2.35  Authoritarian
# 164                    2.22              3.13            0.88  Authoritarian
# 165                    2.78              4.38            0.00  Authoritarian
# 166                    1.67              1.25            0.00  Authoritarian
# 167  Politicalparticipation  Politicalculture  Civilliberties       Category

# %% [markdown]
# First, we see a column that have some messiness (symbol "=" in rank), but which can be deleted as their information is not relevant. Let me get rid of the _Score_, as it is just the mean of the other ones. The last row is the repetition of the headers, so that one should go, too:

# %%
#bye row 167, and two columns
demodexClean=demodex.drop(index=167,columns=['Rank','Score'])

# %%
demodexClean
# Out:
#                               Country Electoral processand pluralism  \
# 0                              Norway                          10.00
# 1                             Iceland                          10.00
# 2                              Sweden                           9.58
# 3                         New Zealand                          10.00
# 4                             Denmark                          10.00
# 5                             Ireland                           9.58
# 6                              Canada                           9.58
# 7                             Finland                          10.00
# 8                           Australia                          10.00
# 9                         Switzerland                           9.58
# 10                        Netherlands                           9.58
# 11                         Luxembourg                          10.00
# 12                            Germany                           9.58
# 13                     United Kingdom                           9.58
# 14                            Uruguay                          10.00
# 15                            Austria                           9.58
# 16                          Mauritius                           9.17
# 17                              Malta                           9.17
# 18                              Spain                           9.17
# 19                         Costa Rica                           9.58
# 20                        South Korea                           9.17
# 21                              Japan                           8.75
# 22                              Chile                           9.58
# 23                            Estonia                           9.58
# 24                      United States                           9.17
# 25                         Cape Verde                           9.17
# 26                           Portugal                           9.58
# 27                           Botswana                           9.17
# 28                             France                           9.58
# 29                             Israel                           9.17
# ..                                ...                            ...
# 137                              Togo                           3.17
# 138                           Vietnam                           0.00
# 139                              Oman                           0.00
# 140                         Swaziland                           0.92
# 141                              Cuba                           1.08
# 142                       Afghanistan                           2.92
# 143                        Kazakhstan                           0.50
# 144                            Russia                           2.17
# 145                          Djibouti                           0.42
# 146              United Arab Emirates                           0.00
# 147                           Bahrain                           0.83
# 148                        Azerbaijan                           0.50
# 149                              Iran                           0.00
# 150                           Eritrea                           0.00
# 151                              Laos                           0.83
# 152                           Burundi                           0.00
# 153                             Libya                           1.00
# 154                             Sudan                           0.00
# 155                        Uzbekistan                           0.08
# 156                     Guinea-Bissau                           1.67
# 157                             Yemen                           0.00
# 158                      Saudi Arabia                           0.00
# 159                        Tajikistan                           0.08
# 160                 Equatorial Guinea                           0.00
# 161                      Turkmenistan                           0.00
# 162                              Chad                           0.00
# 163          Central African Republic                           2.25
# 164  Democratic Republic of the Congo                           0.50
# 165                             Syria                           0.00
# 166                       North Korea                           0.00
#
#     Functioning ofgovernment Politicalparticipation Politicalculture  \
# 0                       9.64                  10.00            10.00
# 29            5.88     Flawed democracy
# ..             ...                  ...
# 137           3.24        Authoritarian
# 138           2.65        Authoritarian
# 139           4.12        Authoritarian
# 140           3.53        Authoritarian
# 141           2.65        Authoritarian
# 142           3.82        Authoritarian
# 143           3.24        Authoritarian
# 144           3.24        Authoritarian
# 145           2.65        Authoritarian
# 146           2.65        Authoritarian
# 147           2.35        Authoritarian
# 148           3.53        Authoritarian
# 149           1.47        Authoritarian
# 150           1.18        Authoritarian
# 151           1.47        Authoritarian
# 152           2.35        Authoritarian
# 153           2.94        Authoritarian
# 154           1.18        Authoritarian
# 155           0.88        Authoritarian
# 156           2.35        Authoritarian
# 157           0.88        Authoritarian
# 158           1.47        Authoritarian
# 159           0.88        Authoritarian
# 160           1.47        Authoritarian
# 161           0.59        Authoritarian
# 162           2.65        Authoritarian
# 163           2.35        Authoritarian
# 164           0.88        Authoritarian
# 165           0.00        Authoritarian
# 166           0.00        Authoritarian
#
# [167 rows x 7 columns]

# %% [markdown]
# As there are few names, we can change to smaller sizes:

# %%
newNames=['plularism','effectiveness','participation','culture','liberties']

# names from the second and before the last one '[1:-1]':
newMapper={old:new for old,new in zip(demodexClean.columns[1:-1],newNames)}

demodexClean.rename(columns=newMapper,inplace=True)

# %%
# this is what we have so far:
demodexClean.head()
# Out:
#        Country plularism effectiveness participation culture liberties  \
# 0       Norway     10.00          9.64         10.00   10.00      9.71
# 1      Iceland     10.00          9.29          8.89   10.00      9.71
# 2       Sweden      9.58          9.64          8.33   10.00      9.41
# 3  New Zealand     10.00          9.29          8.89    8.13     10.00
# 4      Denmark     10.00          9.29          8.33    9.38      9.12
#
#          Category
# 0  Full democracy
# 1  Full democracy
# 2  Full democracy
# 3  Full democracy
# 4  Full democracy

# %% [markdown]
# It looks good so far. Let's go to formatting.
#
# 2. Giving the rigth format:

# %%
# checking data types:
demodexClean.dtypes
# Out:
# Country          object
# plularism        object
# effectiveness    object
# participation    object
# culture          object
# liberties        object
# Category         object
# dtype: object

# %% [markdown]
# Above, we realized the need to make some indices into numeric:

# %%
demodexClean[newNames]=demodexClean[newNames].apply(pd.to_numeric)

# %% [markdown]
# The last one is a categorical variable:

# %%
demodexClean.Category.value_counts()
# Out:
# Flawed democracy       54
# Authoritarian          53
# Hybrid regime          39
# Full democracy         20
# Flawed democracy[a]     1
# Name: Category, dtype: int64

# %% [markdown]
# When you have text, you could get the unique values of a column like this:

# %%
pd.unique(demodexClean.Category).tolist()
# Out:
# ['Full democracy',
#  'Flawed democracy[a]',
#  'Flawed democracy',
#  'Hybrid regime',
#  'Authoritarian']

# %% [markdown]
# Then, you can prepare the map to recode the values:

# %%
oldValues=pd.unique(demodexClean.Category).tolist()
newValues=[4,3,3,2,1]
mapNewOld={old:new for old,new in zip(oldValues,newValues)}
mapNewOld
# Out:
# {'Full democracy': 4,
#  'Flawed democracy[a]': 3,
#  'Flawed democracy': 3,
#  'Hybrid regime': 2,
#  'Authoritarian': 1}

# %% [markdown]
# You can do it in this way:

# %%
demodexClean.Category.replace(mapNewOld,inplace=True)

# %%
# or this one:
# demodexClean.Category=demodexClean.Category.replace(mapNewOld)

# %% [markdown]
# You can save it as a category, but that will be lost if sent to R:

# %%
demodexClean.Category=demodexClean.Category.astype('category')

# %%
demodexClean['Category'].cat.categories
# Out:
# Int64Index([1, 2, 3, 4], dtype='int64')

# %%
# checking missing values

demodexClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167 entries, 0 to 166
# Data columns (total 7 columns):
# Country          167 non-null object
# plularism        167 non-null float64
# effectiveness    167 non-null float64
# participation    167 non-null float64
# culture          167 non-null float64
# liberties        167 non-null float64
# Category         167 non-null category
# dtypes: category(1), float64(5), object(1)
# memory usage: 9.5+ KB

# %% [markdown]
# This data is now ready for R.

# %%
demodexClean.to_csv("democracyIndex.csv",index=None)

# %% [markdown]
# ### The case of Medicare:

# %% [markdown]
# Here I will use data from [Medicare Beneficiary Enrollment and Demographics](https://dev.socrata.com/foundry/data.wa.gov/2cup-2fnu)

# %%
import requests

# This time I am talking to the API from DATA.WA.GOV
url = "https://data.wa.gov/resource/2cup-2fnu.json?year=2014"
response = requests.get(url)
if response.status_code == 200:
    medicare = response.json()

# %%
# turning json into DF:
medicare2014 = pd.DataFrame(medicare)

# %%
medicare2014.head()
# Out:
#   average_age average_hcc_score beneficiaries_with_part_a_and_part_b  \
# 0        71.0              0.90                              1098715
# 1        73.0              0.86                                 1557
# 2        71.0              0.93                                 5426
# 3        71.0              0.92                                28303
# 4        72.0              0.86                                11040
#
#         county ffs_beneficiaries ma_beneficiaries ma_participation_rate  \
# 0  STATE TOTAL            739717           358998                  32.7
# 1        ADAMS              1333              224                  14.4
# 2       ASOTIN              4515              911                  16.8
# 3       BENTON             24054             4249                  15.0
# 4       CHELAN              8884             2156                  19.5
#
#   percent_african_american percent_eligible_for_medicaid percent_female  \
# 0                      2.6                          19.1           53.2
# 1                      NaN                          15.6           51.2
# 2                      NaN                          18.5           51.8
# 3                      0.8                          15.5           53.8
# 4                      0.2                          20.2           51.3
#
#   percent_hispanic percent_male percent_non_hispanic_white  \
# 0              3.4         46.9                       86.3
# 1              NaN         48.8                        NaN
# 2              NaN         48.2                        NaN
# 3              5.1         46.2                       90.0
# 4              5.4         48.7                       91.7
#
#   percent_other_unknown state_and_county_fips_code to_sort_by_county_and_year  \
# 0                   7.7                          .                     0.2014
# 1                   NaN                      53001                  530012014
# 2                   NaN                      53003                  530032014
# 3                   4.1                      53005                  530052014
# 4                   2.7                      53007                  530072014
#
#   to_sort_by_year_and_county  year
# 0                       2014  2014
# 1                  201453001  2014
# 2                  201453003  2014
# 3                  201453005  2014
# 4                  201453007  2014

# %%
medicare2014.tail()
# Out:
#    average_age average_hcc_score beneficiaries_with_part_a_and_part_b  \
# 35        72.0              0.83                                 1249
# 36        73.0              0.95                                11149
# 37        71.0              0.89                                36244
# 38        73.0              0.86                                 4961
# 39        71.0              0.94                                37337
#
#          county ffs_beneficiaries ma_beneficiaries ma_participation_rate  \
# 35    WAHKIAKUM               935              314                  25.1
# 36  WALLA WALLA              9724             1425                  12.8
# 37      WHATCOM             22704            13540                  37.4
# 38      WHITMAN              4770              191                   3.9
# 39       YAKIMA             29424             7913                  21.2
#
#    percent_african_american percent_eligible_for_medicaid percent_female  \
# 35                      NaN                          13.4           48.0
# 36                      0.6                          17.6           55.2
# 37                      0.9                          21.0           52.3
# 38                      0.5                          13.4           53.9
# 39                      1.0                          25.8           53.5
#
#    percent_hispanic percent_male percent_non_hispanic_white  \
# 35              NaN         52.0                        NaN
# 36              5.7         44.9                       91.1
# 37              2.7         47.7                       89.3
# 38              0.9         46.1                       95.0
# 39             15.5         46.5                       78.2
#
#    percent_other_unknown state_and_county_fips_code  \
# 35                   NaN                      53069
# 36                   2.7                      53071
# 37                   7.1                      53073
# 38                   3.7                      53075
# 39                   5.4                      53077
#
#    to_sort_by_county_and_year to_sort_by_year_and_county  year
# 35                  530692014                  201453069  2014
# 36                  530712014                  201453071  2014
# 37                  530732014                  201453073  2014
# 38                  530752014                  201453075  2014
# 39                  530772014                  201453077  2014

# %% [markdown]
# The first row is the total, it has to go:

# %%
#this one?
medicare2014.drop(index=0).head()
# Out:
#   average_age average_hcc_score beneficiaries_with_part_a_and_part_b   county  \
# 1        73.0              0.86                                 1557    ADAMS
# 2        71.0              0.93                                 5426   ASOTIN
# 3        71.0              0.92                                28303   BENTON
# 4        72.0              0.86                                11040   CHELAN
# 5        73.0              0.81                                22429  CLALLAM
#
#   ffs_beneficiaries ma_beneficiaries ma_participation_rate  \
# 1              1333              224                  14.4
# 2              4515              911                  16.8
# 3             24054             4249                  15.0
# 4              8884             2156                  19.5
# 5             20336             2093                   9.3
#
#   percent_african_american percent_eligible_for_medicaid percent_female  \
# 1                      NaN                          15.6           51.2
# 2                      NaN                          18.5           51.8
# 3                      0.8                          15.5           53.8
# 4                      0.2                          20.2           51.3
# 5                      0.3                          12.5           52.6
#
#   percent_hispanic percent_male percent_non_hispanic_white  \
# 1              NaN         48.8                        NaN
# 2              NaN         48.2                        NaN
# 3              5.1         46.2                       90.0
# 4              5.4         48.7                       91.7
# 5              1.3         47.4                       93.3
#
#   percent_other_unknown state_and_county_fips_code to_sort_by_county_and_year  \
# 1                   NaN                      53001                  530012014
# 2                   NaN                      53003                  530032014
# 3                   4.1                      53005                  530052014
# 4                   2.7                      53007                  530072014
# 5                   5.1                      53009                  530092014
#
#   to_sort_by_year_and_county  year
# 1                  201453001  2014
# 2                  201453003  2014
# 3                  201453005  2014
# 4                  201453007  2014
# 5                  201453009  2014

# %%
#or this one?
medicare2014.drop(index=0).reset_index().head()
# Out:
#    index average_age average_hcc_score beneficiaries_with_part_a_and_part_b  \
# 0      1        73.0              0.86                                 1557
# 1      2        71.0              0.93                                 5426
# 2      3        71.0              0.92                                28303
# 3      4        72.0              0.86                                11040
# 4      5        73.0              0.81                                22429
#
#     county ffs_beneficiaries ma_beneficiaries ma_participation_rate  \
# 0    ADAMS              1333              224                  14.4
# 1   ASOTIN              4515              911                  16.8
# 2   BENTON             24054             4249                  15.0
# 3   CHELAN              8884             2156                  19.5
# 4  CLALLAM             20336             2093                   9.3
#
#   percent_african_american percent_eligible_for_medicaid percent_female  \
# 0                      NaN                          15.6           51.2
# 1                      NaN                          18.5           51.8
# 2                      0.8                          15.5           53.8
# 3                      0.2                          20.2           51.3
# 4                      0.3                          12.5           52.6
#
#   percent_hispanic percent_male percent_non_hispanic_white  \
# 0              NaN         48.8                        NaN
# 1              NaN         48.2                        NaN
# 2              5.1         46.2                       90.0
# 3              5.4         48.7                       91.7
# 4              1.3         47.4                       93.3
#
#   percent_other_unknown state_and_county_fips_code to_sort_by_county_and_year  \
# 0                   NaN                      53001                  530012014
# 1                   NaN                      53003                  530032014
# 2                   4.1                      53005                  530052014
# 3                   2.7                      53007                  530072014
# 4                   5.1                      53009                  530092014
#
#   to_sort_by_year_and_county  year
# 0                  201453001  2014
# 1                  201453003  2014
# 2                  201453005  2014
# 3                  201453007  2014
# 4                  201453009  2014

# %%
#or this one?
medicare2014.drop(index=0).reset_index(drop=True).head()
# Out:
#   average_age average_hcc_score beneficiaries_with_part_a_and_part_b   county  \
# 0        73.0              0.86                                 1557    ADAMS
# 1        71.0              0.93                                 5426   ASOTIN
# 2        71.0              0.92                                28303   BENTON
# 3        72.0              0.86                                11040   CHELAN
# 4        73.0              0.81                                22429  CLALLAM
#
#   ffs_beneficiaries ma_beneficiaries ma_participation_rate  \
# 0              1333              224                  14.4
# 1              4515              911                  16.8
# 2             24054             4249                  15.0
# 3              8884             2156                  19.5
# 4             20336             2093                   9.3
#
#   percent_african_american percent_eligible_for_medicaid percent_female  \
# 0                      NaN                          15.6           51.2
# 1                      NaN                          18.5           51.8
# 2                      0.8                          15.5           53.8
# 3                      0.2                          20.2           51.3
# 4                      0.3                          12.5           52.6
#
#   percent_hispanic percent_male percent_non_hispanic_white  \
# 0              NaN         48.8                        NaN
# 1              NaN         48.2                        NaN
# 2              5.1         46.2                       90.0
# 3              5.4         48.7                       91.7
# 4              1.3         47.4                       93.3
#
#   percent_other_unknown state_and_county_fips_code to_sort_by_county_and_year  \
# 0                   NaN                      53001                  530012014
# 1                   NaN                      53003                  530032014
# 2                   4.1                      53005                  530052014
# 3                   2.7                      53007                  530072014
# 4                   5.1                      53009                  530092014
#
#   to_sort_by_year_and_county  year
# 0                  201453001  2014
# 1                  201453003  2014
# 2                  201453005  2014
# 3                  201453007  2014
# 4                  201453009  2014

# %% [markdown]
# When we use inplace, we should not concatenate:

# %%
medicare2014.drop(index=0,inplace=True)
medicare2014.reset_index(drop=True,inplace=True)

# %% [markdown]
# The result so far:

# %%
medicare2014.head()
# Out:
#   average_age average_hcc_score beneficiaries_with_part_a_and_part_b   county  \
# 0        73.0              0.86                                 1557    ADAMS
# 1        71.0              0.93                                 5426   ASOTIN
# 2        71.0              0.92                                28303   BENTON
# 3        72.0              0.86                                11040   CHELAN
# 4        73.0              0.81                                22429  CLALLAM
#
#   ffs_beneficiaries ma_beneficiaries ma_participation_rate  \
# 0              1333              224                  14.4
# 1              4515              911                  16.8
# 2             24054             4249                  15.0
# 3              8884             2156                  19.5
# 4             20336             2093                   9.3
#
#   percent_african_american percent_eligible_for_medicaid percent_female  \
# 0                      NaN                          15.6           51.2
# 1                      NaN                          18.5           51.8
# 2                      0.8                          15.5           53.8
# 3                      0.2                          20.2           51.3
# 4                      0.3                          12.5           52.6
#
#   percent_hispanic percent_male percent_non_hispanic_white  \
# 0              NaN         48.8                        NaN
# 1              NaN         48.2                        NaN
# 2              5.1         46.2                       90.0
# 3              5.4         48.7                       91.7
# 4              1.3         47.4                       93.3
#
#   percent_other_unknown state_and_county_fips_code to_sort_by_county_and_year  \
# 0                   NaN                      53001                  530012014
# 1                   NaN                      53003                  530032014
# 2                   4.1                      53005                  530052014
# 3                   2.7                      53007                  530072014
# 4                   5.1                      53009                  530092014
#
#   to_sort_by_year_and_county  year
# 0                  201453001  2014
# 1                  201453003  2014
# 2                  201453005  2014
# 3                  201453007  2014
# 4                  201453009  2014

# %%
# what we have
medicare2014.dtypes
# Out:
# average_age                             object
# average_hcc_score                       object
# beneficiaries_with_part_a_and_part_b    object
# county                                  object
# ffs_beneficiaries                       object
# ma_beneficiaries                        object
# ma_participation_rate                   object
# percent_african_american                object
# percent_eligible_for_medicaid           object
# percent_female                          object
# percent_hispanic                        object
# percent_male                            object
# percent_non_hispanic_white              object
# percent_other_unknown                   object
# state_and_county_fips_code              object
# to_sort_by_county_and_year              object
# to_sort_by_year_and_county              object
# year                                    object
# dtype: object

# %% [markdown]
# Notice that the three variables before the last one, and county should be kept as objects, while the other should be numeric:

# %%
# get original order:
original=medicare2014.columns.tolist()
original
# Out:
# ['average_age',
#  'average_hcc_score',
#  'beneficiaries_with_part_a_and_part_b',
#  'county',
#  'ffs_beneficiaries',
#  'ma_beneficiaries',
#  'ma_participation_rate',
#  'percent_african_american',
#  'percent_eligible_for_medicaid',
#  'percent_female',
#  'percent_hispanic',
#  'percent_male',
#  'percent_non_hispanic_white',
#  'percent_other_unknown',
#  'state_and_county_fips_code',
#  'to_sort_by_county_and_year',
#  'to_sort_by_year_and_county',
#  'year']

# %%
# new order:  (no need for * if one element)
newOrder=[original[3],*original[14:], *original[0:3],*original[4:14],] # using '*'
newOrder
# Out:
# ['county',
#  'state_and_county_fips_code',
#  'to_sort_by_county_and_year',
#  'to_sort_by_year_and_county',
#  'year',
#  'average_age',
#  'average_hcc_score',
#  'beneficiaries_with_part_a_and_part_b',
#  'ffs_beneficiaries',
#  'ma_beneficiaries',
#  'ma_participation_rate',
#  'percent_african_american',
#  'percent_eligible_for_medicaid',
#  'percent_female',
#  'percent_hispanic',
#  'percent_male',
#  'percent_non_hispanic_white',
#  'percent_other_unknown']

# %%
# there are differenet data types, let me move columns:

medicare2014=medicare2014[newOrder]
medicare2014.head()
# Out:
#     county state_and_county_fips_code to_sort_by_county_and_year  \
# 0    ADAMS                      53001                  530012014
# 1   ASOTIN                      53003                  530032014
# 2   BENTON                      53005                  530052014
# 3   CHELAN                      53007                  530072014
# 4  CLALLAM                      53009                  530092014
#
#   to_sort_by_year_and_county  year average_age average_hcc_score  \
# 0                  201453001  2014        73.0              0.86
# 1                  201453003  2014        71.0              0.93
# 2                  201453005  2014        71.0              0.92
# 3                  201453007  2014        72.0              0.86
# 4                  201453009  2014        73.0              0.81
#
#   beneficiaries_with_part_a_and_part_b ffs_beneficiaries ma_beneficiaries  \
# 0                                 1557              1333              224
# 1                                 5426              4515              911
# 2                                28303             24054             4249
# 3                                11040              8884             2156
# 4                                22429             20336             2093
#
#   ma_participation_rate percent_african_american  \
# 0                  14.4                      NaN
# 1                  16.8                      NaN
# 2                  15.0                      0.8
# 3                  19.5                      0.2
# 4                   9.3                      0.3
#
#   percent_eligible_for_medicaid percent_female percent_hispanic percent_male  \
# 0                          15.6           51.2              NaN         48.8
# 1                          18.5           51.8              NaN         48.2
# 2                          15.5           53.8              5.1         46.2
# 3                          20.2           51.3              5.4         48.7
# 4                          12.5           52.6              1.3         47.4
#
#   percent_non_hispanic_white percent_other_unknown
# 0                        NaN                   NaN
# 1                        NaN                   NaN
# 2                       90.0                   4.1
# 3                       91.7                   2.7
# 4                       93.3                   5.1

# %% [markdown]
# 2. Formatting

# %% [markdown]
# We can give the right format now:

# %%
headerNames=medicare2014.columns
medicare2014[headerNames[4::]]=medicare2014[headerNames[4::]].apply(pd.to_numeric)

# %%
#check data types:
medicare2014.dtypes
# Out:
# county                                   object
# state_and_county_fips_code               object
# to_sort_by_county_and_year               object
# to_sort_by_year_and_county               object
# year                                      int64
# average_age                             float64
# average_hcc_score                       float64
# beneficiaries_with_part_a_and_part_b      int64
# ffs_beneficiaries                         int64
# ma_beneficiaries                          int64
# ma_participation_rate                   float64
# percent_african_american                float64
# percent_eligible_for_medicaid           float64
# percent_female                          float64
# percent_hispanic                        float64
# percent_male                            float64
# percent_non_hispanic_white              float64
# percent_other_unknown                   float64
# dtype: object

# %% [markdown]
# We can explore the variables:

# %%
medicare2014.describe(include='all') # to include categorical
# Out:
#        county state_and_county_fips_code to_sort_by_county_and_year  \
# count      39                         39                         39
# unique     39                         39                         39
# top     LEWIS                      53015                  530772014
# freq        1                          1                          1
# mean      NaN                        NaN                        NaN
# std       NaN                        NaN                        NaN
# min       NaN                        NaN                        NaN
# 25%       NaN                        NaN                        NaN
# 50%       NaN                        NaN                        NaN
# 75%       NaN                        NaN                        NaN
# max       NaN                        NaN                        NaN
#
#        to_sort_by_year_and_county    year  average_age  average_hcc_score  \
# count                          39    39.0    39.000000          39.000000
# unique                         39     NaN          NaN                NaN
# top                     201453043     NaN          NaN                NaN
# freq                            1     NaN          NaN                NaN
# mean                          NaN  2014.0    71.384615           0.852051
# std                           NaN     0.0     1.091001           0.074699
# min                           NaN  2014.0    69.000000           0.670000
# 25%                           NaN  2014.0    71.000000           0.790000
# 50%                           NaN  2014.0    71.000000           0.860000
# 75%                           NaN  2014.0    72.000000           0.925000
# max                           NaN  2014.0    73.000000           0.990000
#
#         beneficiaries_with_part_a_and_part_b  ffs_beneficiaries  \
# count                              39.000000          39.000000
# unique                                   NaN                NaN
# top                                      NaN                NaN
# freq                                     NaN                NaN
# mean                            28172.179487       18967.102564
# std                             47845.550778       29514.437571
# min                               617.000000         600.000000
# 25%                              4926.500000        4529.500000
# 50%                             11040.000000        9335.000000
# 75%                             26892.000000       21520.000000
# max                            264388.000000      164731.000000
#
#         ma_beneficiaries  ma_participation_rate  percent_african_american  \
# count          39.000000              39.000000                  30.00000
# unique               NaN                    NaN                       NaN
# top                  NaN                    NaN                       NaN
# freq                 NaN                    NaN                       NaN
# mean         9205.076923              19.910256                   1.11000
# std         18921.743351              13.816348                   1.40721
# min            17.000000               2.800000                   0.20000
# 25%           379.500000               8.850000                   0.40000
# 50%          1439.000000              16.300000                   0.55000
# 75%          8036.000000              31.000000                   1.15000
# max         99657.000000              56.100000                   6.00000
#
#         percent_eligible_for_medicaid  percent_female  percent_hispanic  \
# count                       39.000000       39.000000         30.000000
# unique                            NaN             NaN               NaN
# top                               NaN             NaN               NaN
# freq                              NaN             NaN               NaN
# mean                        17.258974       51.820513          3.813333
# std                          4.126597        1.842507          4.360618
# min                          8.400000       47.400000          0.800000
# 25%                         14.800000       50.950000          1.525000
# 50%                         16.800000       51.800000          2.550000
# 75%                         20.150000       53.250000          3.350000
# max                         26.000000       55.200000         19.400000
#
#         percent_male  percent_non_hispanic_white  percent_other_unknown
# count      39.000000                   30.000000              30.000000
# unique           NaN                         NaN                    NaN
# top              NaN                         NaN                    NaN
# freq             NaN                         NaN                    NaN
# mean       48.187179                   89.923333               5.176667
# std         1.842935                    5.657932               2.599958
# min        44.900000                   73.900000               2.400000
# 25%        46.750000                   87.975000               3.600000
# 50%        48.200000                   91.800000               4.300000
# 75%        49.050000                   94.075000               6.525000
# max        52.600000                   95.500000              13.600000

# %%
medicare2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 18 columns):
# county                                  39 non-null object
# state_and_county_fips_code              39 non-null object
# to_sort_by_county_and_year              39 non-null object
# to_sort_by_year_and_county              39 non-null object
# year                                    39 non-null int64
# average_age                             39 non-null float64
# average_hcc_score                       39 non-null float64
# beneficiaries_with_part_a_and_part_b    39 non-null int64
# ffs_beneficiaries                       39 non-null int64
# ma_beneficiaries                        39 non-null int64
# ma_participation_rate                   39 non-null float64
# percent_african_american                30 non-null float64
# percent_eligible_for_medicaid           39 non-null float64
# percent_female                          39 non-null float64
# percent_hispanic                        30 non-null float64
# percent_male                            39 non-null float64
# percent_non_hispanic_white              30 non-null float64
# percent_other_unknown                   30 non-null float64
# dtypes: float64(10), int64(4), object(4)
# memory usage: 5.6+ KB

# %% [markdown]
# There are some missing values, but we will leave it so. So the last step will be just to save the file:

# %%
medicare2014.to_csv("medicare2014.csv",index=None)

# %% [markdown]
# ### Case: Public education:
#
# When you visit the [website](https://nces.ed.gov/ccd/) of the Common Core of Data from the US Department of Education, you can get a data set with detailed information on public schools at the state of Washington:

# %%
dataFile='https://github.com/EvansDataScience/data/raw/master/wapubs.xlsx'
schoolPub=pd.read_excel(dataFile)

# %% [markdown]
# 1. Looking for messiness:

# %%
schoolPub.head(20)
# Out:
#              National Center for Education Statistics       Unnamed: 1  \
# 0        CCD public school data 2014-2015 school year              NaN
# 1   The file contains (2398) records based on your...              NaN
# 2                                              NOTES:              NaN
# 3                                                 NaN              NaN
# 4   [ † ] indicates that the data are not applicable.              NaN
# 5          [ – ] indicates that the data are missing.              NaN
# 6   [ ‡ ] indicates that the data do not meet NCES...              NaN
# 7                                                 NaN              NaN
# 8   SEARCH CRITERIA: State: "Washington" - School ...              NaN
# 9   NCES is not responsible for the manner in whic...              NaN
# 10                                     NCES School ID  State School ID
# 11                                       530486002475             1656
# 12                                       530270001270             1646
# 13                                       530910002602             4500
# 14                                       530003000001             2834
# 15                                       530825002361             1533
# 16                                       530966001632             3209
# 17                                       530354003069             5063
# 18                                       530486003325             5209
# 19                                       530048003466             5372
#
#           Unnamed: 2         Unnamed: 3  Unnamed: 4   Unnamed: 5  \
# 0                NaN                NaN         NaN          NaN
# 1                NaN                NaN         NaN          NaN
# 2                NaN                NaN         NaN          NaN
# 3                NaN                NaN         NaN          NaN
# 4                NaN                NaN         NaN          NaN
# 5                NaN                NaN         NaN          NaN
# 6                NaN                NaN         NaN          NaN
# 7                NaN                NaN         NaN          NaN
# 8                NaN                NaN         NaN          NaN
# 9                NaN                NaN         NaN          NaN
# 10  NCES District ID  State District ID  Low Grade*  High Grade*
# 11           5304860              31025          06           08
# 12           5302700              06114          KG           12
# 13           5309100              34033          09           12
# 14           5300030              14005          PK           06
# 15           5308250              32081          09           12
# 16           5309660              04246          KG           05
# 17           5303540              17401          09           12
# 18           5304860              31025          09           12
# 19           5300480              27403          09           12
#
#                                 Unnamed: 6                         Unnamed: 7  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
# 5                                      NaN                                NaN
# 6                                      NaN                                NaN
# 7                                      NaN                                NaN
# 8                                      NaN                                NaN
# 9                                      NaN                                NaN
# 10                             School Name                           District
# 11                      10TH STREET SCHOOL         MARYSVILLE SCHOOL DISTRICT
# 12                     49TH STREET ACADEMY  EVERGREEN SCHOOL DISTRICT (CLARK)
# 13        A G WEST BLACK HILLS HIGH SCHOOL           TUMWATER SCHOOL DISTRICT
# 14                     A J WEST ELEMENTARY           ABERDEEN SCHOOL DISTRICT
# 15         A-3 MULTIAGENCY ADOLESCENT PROG            SPOKANE SCHOOL DISTRICT
# 16              ABRAHAM LINCOLN ELEMENTARY          WENATCHEE SCHOOL DISTRICT
# 17  ACADEMY OF CITIZENSHIP AND EMPOWERMENT           HIGHLINE SCHOOL DISTRICT
# 18        ACADEMY OF CONST AND ENGINEERING         MARYSVILLE SCHOOL DISTRICT
# 19                    ACCELERATION ACADEMY             BETHEL SCHOOL DISTRICT
#
#              Unnamed: 8                  Unnamed: 9       ...        \
# 0                   NaN                         NaN       ...
# 1                   NaN                         NaN       ...
# 2                   NaN                         NaN       ...
# 3                   NaN                         NaN       ...
# 4                   NaN                         NaN       ...
# 5                   NaN                         NaN       ...
# 6                   NaN                         NaN       ...
# 7                   NaN                         NaN       ...
# 8                   NaN                         NaN       ...
# 9                   NaN                         NaN       ...
# 10         County Name*              Street Address       ...
# 11     SNOHOMISH COUNTY            7204 27TH AVE NE       ...
# 12         CLARK COUNTY       14619B NE 49TH STREET       ...
# 13      THURSTON COUNTY     7741 LITTLEROCK ROAD SW       ...
# 14  GRAYS HARBOR COUNTY               1801 BAY AVE.       ...
# 15       SPOKANE COUNTY  610 E NORTHFOOTHILLS DRIVE       ...
# 16        CHELAN COUNTY             1224 METHOW ST.       ...
# 17          KING COUNTY     4424 SOUTH 188TH STREET       ...
# 18     SNOHOMISH COUNTY         8301 84TH STREET NE       ...
# 19        PIERCE COUNTY           16218 PACIFIC AVE       ...
#
#         Unnamed: 16 Unnamed: 17 Unnamed: 18      Unnamed: 19  \
# 0               NaN         NaN         NaN              NaN
# 1               NaN         NaN         NaN              NaN
# 2               NaN         NaN         NaN              NaN
# 3               NaN         NaN         NaN              NaN
# 4               NaN         NaN         NaN              NaN
# 5               NaN         NaN         NaN              NaN
# 6               NaN         NaN         NaN              NaN
# 7               NaN         NaN         NaN              NaN
# 8               NaN         NaN         NaN              NaN
# 9               NaN         NaN         NaN              NaN
# 10          Locale*     Charter     Magnet*  Title I School*
# 11  Suburb: Midsize          No           –               No
# 12    City: Midsize          No           –              Yes
# 13      City: Small          No           –               No
# 14     Town: Remote          No           –              Yes
# 15    City: Midsize          No           –               No
# 16      City: Small          No           –              Yes
# 17    Suburb: Large          No           –              Yes
# 18  Suburb: Midsize          No           –              Yes
# 19    Suburb: Large          No           –               No
#
#              Unnamed: 20 Unnamed: 21 Unnamed: 22             Unnamed: 23  \
# 0                    NaN         NaN         NaN                     NaN
# 1                    NaN         NaN         NaN                     NaN
# 2                    NaN         NaN         NaN                     NaN
# 3                    NaN         NaN         NaN                     NaN
# 4                    NaN         NaN         NaN                     NaN
# 5                    NaN         NaN         NaN                     NaN
# 6                    NaN         NaN         NaN                     NaN
# 7                    NaN         NaN         NaN                     NaN
# 8                    NaN         NaN         NaN                     NaN
# 9                    NaN         NaN         NaN                     NaN
# 10  Title 1 School Wide*   Students*   Teachers*  Student Teacher Ratio*
# 11                     †   167.00000     7.30000              22.9000000
# 12                   Yes   123.00000    10.10000              12.2000000
# 13                     †   867.00000    41.19000              21.0000000
# 14                   Yes   410.00000    27.63000              14.8000000
# 15                     †    22.00000     3.10000               7.1000000
# 16                   Yes   514.00000    40.05000              12.8000000
# 17                   Yes   433.00000    18.28000              23.7000000
# 18                   Yes   325.00000    16.20000              20.1000000
# 19                     †   102.00000           –                       †
#
#     Unnamed: 24     Unnamed: 25
# 0           NaN             NaN
# 1           NaN             NaN
# 2           NaN             NaN
# 3           NaN             NaN
# 4           NaN             NaN
# 5           NaN             NaN
# 6           NaN             NaN
# 7           NaN             NaN
# 8           NaN             NaN
# 9           NaN             NaN
# 10  Free Lunch*  Reduced Lunch*
# 11     20.00000         7.00000
# 12     75.00000         7.00000
# 13    189.00000        45.00000
# 14    330.00000        21.00000
# 15     16.00000         3.00000
# 16    361.00000        42.00000
# 17    295.00000        24.00000
# 18    131.00000        35.00000
# 19     39.00000         8.00000
#
# [20 rows x 26 columns]

# %% [markdown]
# The first row is not the beginning of the table. We need to skip 11 rows; but pay attention to what you are deleting, as if is telling you how missing values were coded.

# %%
schoolPub=pd.read_excel(dataFile,skiprows=11,na_values=['†','‡','–'])
schoolPub.head()
# Out:
#    NCES School ID  State School ID  NCES District ID  State District ID  \
# 0    530486002475             1656           5304860              31025
# 1    530270001270             1646           5302700               6114
# 2    530910002602             4500           5309100              34033
# 3    530003000001             2834           5300030              14005
# 4    530825002361             1533           5308250              32081
#
#   Low Grade* High Grade*                       School Name  \
# 0         06          08                10TH STREET SCHOOL
# 1         KG          12               49TH STREET ACADEMY
# 2         09          12  A G WEST BLACK HILLS HIGH SCHOOL
# 3         PK          06               A J WEST ELEMENTARY
# 4         09          12   A-3 MULTIAGENCY ADOLESCENT PROG
#
#                             District         County Name*  \
# 0         MARYSVILLE SCHOOL DISTRICT     SNOHOMISH COUNTY
# 1  EVERGREEN SCHOOL DISTRICT (CLARK)         CLARK COUNTY
# 2           TUMWATER SCHOOL DISTRICT      THURSTON COUNTY
# 3           ABERDEEN SCHOOL DISTRICT  GRAYS HARBOR COUNTY
# 4            SPOKANE SCHOOL DISTRICT       SPOKANE COUNTY
#
#                Street Address      ...                Locale* Charter  \
# 0            7204 27TH AVE NE      ...        Suburb: Midsize      No
# 1       14619B NE 49TH STREET      ...          City: Midsize      No
# 2     7741 LITTLEROCK ROAD SW      ...            City: Small      No
# 3               1801 BAY AVE.      ...           Town: Remote      No
# 4  610 E NORTHFOOTHILLS DRIVE      ...          City: Midsize      No
#
#    Magnet*  Title I School*  Title 1 School Wide*  Students* Teachers*  \
# 0      NaN               No                   NaN      167.0      7.30
# 1      NaN              Yes                   Yes      123.0     10.10
# 2      NaN               No                   NaN      867.0     41.19
# 3      NaN              Yes                   Yes      410.0     27.63
# 4      NaN               No                   NaN       22.0      3.10
#
#   Student Teacher Ratio*  Free Lunch* Reduced Lunch*
# 0                   22.9         20.0            7.0
# 1                   12.2         75.0            7.0
# 2                   21.0        189.0           45.0
# 3                   14.8        330.0           21.0
# 4                    7.1         16.0            3.0
#
# [5 rows x 26 columns]

# %%
#checking the tail:
schoolPub.tail()
# Out:
#       NCES School ID  State School ID  NCES District ID  State District ID  \
# 2393    530813003439             5315           5308130              17406
# 2394    530696002530             4496           5306960              27003
# 2395    531017001719             2240           5310170              39205
# 2396    531017001896             4221           5310170              39205
# 2397    531017002502             4481           5310170              39205
#
#      Low Grade* High Grade*                 School Name  \
# 2393         09          12                 YOUTHSOURCE
# 2394         PK          06           ZEIGER ELEMENTARY
# 2395         09          12          ZILLAH HIGH SCHOOL
# 2396         04          06  ZILLAH INTERMEDIATE SCHOOL
# 2397         07          08        ZILLAH MIDDLE SCHOOL
#
#                       District   County Name*           Street Address  \
# 2393   TUKWILA SCHOOL DISTRICT    KING COUNTY  TUKWILA SCHOOL DISTRICT
# 2394  PUYALLUP SCHOOL DISTRICT  PIERCE COUNTY         13008 94TH AVE E
# 2395    ZILLAH SCHOOL DISTRICT  YAKIMA COUNTY       1602 SECOND AVENUE
# 2396    ZILLAH SCHOOL DISTRICT  YAKIMA COUNTY        303 SECOND AVENUE
# 2397    ZILLAH SCHOOL DISTRICT  YAKIMA COUNTY          1301 CUTLER WAY
#
#           ...              Locale* Charter  Magnet*  Title I School*  \
# 2393      ...          City: Small      No      NaN              NaN
# 2394      ...        Suburb: Large      No      NaN               No
# 2395      ...        Town: Distant      No      NaN              Yes
# 2396      ...        Town: Distant      No      NaN              Yes
# 2397      ...        Rural: Fringe      No      NaN              Yes
#
#       Title 1 School Wide*  Students* Teachers* Student Teacher Ratio*  \
# 2393                   NaN        0.0       NaN                    NaN
# 2394                   NaN      823.0     44.53                   18.5
# 2395                   Yes      441.0     21.95                   20.1
# 2396                   Yes      319.0     20.38                   15.7
# 2397                   Yes      196.0     12.65                   15.5
#
#       Free Lunch* Reduced Lunch*
# 2393          0.0            0.0
# 2394        221.0           58.0
# 2395        169.0           49.0
# 2396        145.0           42.0
# 2397         91.0           19.0
#
# [5 rows x 26 columns]

# %% [markdown]
# The headers have blanks and symbols, getting rid of them here:

# %%
import re

pattern='\\*|\\s+'
nothing=''
schoolPub.columns=[re.sub(pattern,nothing,columnName) for columnName in schoolPub.columns]
schoolPub.columns
# Out:
# Index(['NCESSchoolID', 'StateSchoolID', 'NCESDistrictID', 'StateDistrictID',
#        'LowGrade', 'HighGrade', 'SchoolName', 'District', 'CountyName',
#        'StreetAddress', 'City', 'State', 'ZIP', 'ZIP4-digit', 'Phone',
#        'LocaleCode', 'Locale', 'Charter', 'Magnet', 'TitleISchool',
#        'Title1SchoolWide', 'Students', 'Teachers', 'StudentTeacherRatio',
#        'FreeLunch', 'ReducedLunch'],
#       dtype='object')

# %% [markdown]
# Clean names allow better exploring. Notice we solved the missing values above. You could have done this instead:

# %%
symbolsForNA=['†','‡','–'] 

import numpy as np  #numpy manages the nan for pandas
schoolPub.replace(symbolsForNA,np.nan,inplace=True) # in the whole data frame!!

# %% [markdown]
# 2. Formatting

# %%
schoolPub.dtypes
# Out:
# NCESSchoolID             int64
# StateSchoolID            int64
# NCESDistrictID           int64
# StateDistrictID          int64
# LowGrade                object
# HighGrade               object
# SchoolName              object
# District                object
# CountyName              object
# StreetAddress           object
# City                    object
# State                   object
# ZIP                      int64
# ZIP4-digit             float64
# Phone                    int64
# LocaleCode             float64
# Locale                  object
# Charter                 object
# Magnet                 float64
# TitleISchool            object
# Title1SchoolWide        object
# Students               float64
# Teachers               float64
# StudentTeacherRatio    float64
# FreeLunch              float64
# ReducedLunch           float64
# dtype: object

# %% [markdown]
# Even though we cleaned the missing values, there might be more in the text columns that may be hidden. Obviously, 'SchoolName','District','CountyName','StreetAddress','City','State' are text, but the other are possibly categorical.
#
# So let me explore all the other ones, which are of type _object_:

# %%
notUsed=['SchoolName','District','CountyName','StreetAddress','City','State']
 
# These are the ones without the obvious text columns
schoolPub.drop(notUsed,axis=1).head()
# Out:
#    NCESSchoolID  StateSchoolID  NCESDistrictID  StateDistrictID LowGrade  \
# 0  530486002475           1656         5304860            31025       06
# 1  530270001270           1646         5302700             6114       KG
# 2  530910002602           4500         5309100            34033       09
# 3  530003000001           2834         5300030            14005       PK
# 4  530825002361           1533         5308250            32081       09
#
#   HighGrade    ZIP  ZIP4-digit       Phone  LocaleCode           Locale  \
# 0        08  98271         NaN  3606530665        22.0  Suburb: Midsize
# 1        12  98682      6308.0  3606046700        12.0    City: Midsize
# 2        12  98512      7427.0  3607097800        13.0      City: Small
# 3        06  98520      5510.0  3605382131        33.0     Town: Remote
# 4        12  99207         NaN  5094587466        12.0    City: Midsize
#
#   Charter  Magnet TitleISchool Title1SchoolWide  Students  Teachers  \
# 0      No     NaN           No              NaN     167.0      7.30
# 1      No     NaN          Yes              Yes     123.0     10.10
# 2      No     NaN           No              NaN     867.0     41.19
# 3      No     NaN          Yes              Yes     410.0     27.63
# 4      No     NaN           No              NaN      22.0      3.10
#
#    StudentTeacherRatio  FreeLunch  ReducedLunch
# 0                 22.9       20.0           7.0
# 1                 12.2       75.0           7.0
# 2                 21.0      189.0          45.0
# 3                 14.8      330.0          21.0
# 4                  7.1       16.0           3.0

# %%
# # These are the ones without the obvious text columns, but of the type 'object':
schoolPub.drop(notUsed,axis=1).select_dtypes(include='object').head()
# Out:
#   LowGrade HighGrade           Locale Charter TitleISchool Title1SchoolWide
# 0       06        08  Suburb: Midsize      No           No              NaN
# 1       KG        12    City: Midsize      No          Yes              Yes
# 2       09        12      City: Small      No           No              NaN
# 3       PK        06     Town: Remote      No          Yes              Yes
# 4       09        12    City: Midsize      No           No              NaN

# %% [markdown]
# We need to see the categories there:

# %%
schoolPub.drop(notUsed,axis=1).select_dtypes(include='object').apply(set).tolist()
# Out:
# [{'01',
#   '02',
#   '03',
#   '04',
#   '05',
#   '06',
#   '07',
#   '08',
#   '09',
#   '10',
#   '11',
#   '12',
#   'KG',
#   'PK',
#   nan},
#  {'01',
#   '02',
#   '03',
#   '04',
#   '05',
#   '06',
#   '07',
#   '08',
#   '09',
#   '10',
#   '11',
#   '12',
#   '13',
#   'KG',
#   'PK',
#   nan},
#  {'City: Large',
#   'City: Midsize',
#   'City: Small',
#   'N',
#   'Rural: Distant',
#   'Rural: Fringe',
#   'Rural: Remote',
#   'Suburb: Large',
#   'Suburb: Midsize',
#   'Suburb: Small',
#   'Town: Distant',
#   'Town: Fringe',
#   'Town: Remote'},
#  {'No', 'Yes'},
#  {'No', 'Yes', nan},
#  {'No', 'Yes', nan}]

# %% [markdown]
# We need to take care of the missing value '**N**':

# %%
schoolPub.Locale.value_counts(dropna=False)
# Out:
# Suburb: Large      580
# City: Small        368
# City: Midsize      246
# Rural: Fringe      199
# Suburb: Midsize    186
# Rural: Distant     172
# Town: Distant      157
# Rural: Remote      139
# City: Large        111
# Town: Fringe        97
# Town: Remote        85
# Suburb: Small       57
# N                    1
# Name: Locale, dtype: int64

# %% [markdown]
# Then:

# %%
import numpy as np  #numpy manages the nan for pandas

schoolPub.replace(['N'],np.nan,inplace=True) # in the whole data frame!!

# %%
# So:
schoolPub.Locale.value_counts(dropna=False)
# Out:
# Suburb: Large      580
# City: Small        368
# City: Midsize      246
# Rural: Fringe      199
# Suburb: Midsize    186
# Rural: Distant     172
# Town: Distant      157
# Rural: Remote      139
# City: Large        111
# Town: Fringe        97
# Town: Remote        85
# Suburb: Small       57
# NaN                  1
# Name: Locale, dtype: int64

# %% [markdown]
# Another important step could be to give add some text to make the school grades a recognizable ordering (considering the file will be read in R:

# %%
# this is wrong:
'PK'<'KG'<'01'
# Out:
# False

# %%
# this is OK:
'-1 PK'<'0 KG'<'01'
# Out:
# True

# %%
# using replace:

schoolPub.replace({'PK':"-1 PK", "KG":"0 KG"},inplace=True)

# %% [markdown]
# Unless you want to recode other [variables](https://nces.ed.gov/programs/edge/docs/LOCALE_CLASSIFICATIONS.pdf), we could save this file:

# %%
schoolPub.to_csv("schoolPub.csv",index=None)

# %% [markdown]
# ### Case: SNAP

# %%
import pandas as pd
dataFile="https://github.com/EvansDataScience/data/raw/master/cntysnap.xls"
snapBen=pd.read_excel(dataFile)

# %%
# first rows:
snapBen.head()
# Out:
#                   Table with column headers in row 3        Unnamed: 1  \
# 0  Table:  County SNAP benefits recipients\nSourc...               NaN
# 1                                    State FIPS code  County FIPS code
# 2                                                  1                 0
# 3                                                  1                 1
# 4                                                  1                 3
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                Name  July 2013  July 2012  July 2011  July 2010  July 2009
# 2             Alabama     905604     914740     905658     859695     780427
# 3  Autauga County, AL       8055       8079       8060       7593       6907
# 4  Baldwin County, AL      24402      23169      22184      20604      16545
#
#   Unnamed: 8 Unnamed: 9     ...     Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 0        NaN        NaN     ...             NaN         NaN         NaN
# 1  July 2008  July 2007     ...       July 2003   July 2002   July 2001
# 2     642427     561024     ...          491910      463998      435235
# 3       5423       4686     ...            3594        3352        3035
# 4      10848       8627     ...            5659        4945        4129
#
#   Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1   July 2000   July 1999   July 1998   July 1997   July 1995   July 1993
# 2      405325      396931      409160      434632      510271      561128
# 3        2814        2700        2589        2771        3611        4608
# 4        4178        4372        4850        5201        6928        8053
#
#   Unnamed: 22
# 0         NaN
# 1   July 1989
# 2      435296
# 3        3739
# 4        5548
#
# [5 rows x 23 columns]

# %% [markdown]
# We need to skip some rows:

# %%
# skipping:

snapBen=pd.read_excel(dataFile,skiprows=2)
snapBen.head()
# Out:
#    State FIPS code  County FIPS code                Name  July 2013  \
# 0                1                 0             Alabama   905604.0
# 2408    44409.0    45227.0    49790.0    55514.0    49514.0
# 2475   517299.0   546662.0   640336.0   782500.0   494625.0
# 2571  1442124.0  1723403.0  2423614.0  2677888.0  1659004.0
# 2826    89292.0    92822.0   111564.0   126833.0    94368.0
# 2856    45047.0    49598.0    57098.0    57128.0    36667.0
# 2871   367932.0   412457.0   542171.0   545005.0   325488.0
# 3008   318497.0   380224.0   473821.0   456829.0   265611.0
# 3048   252191.0   273287.0   301630.0   320351.0   263330.0
# 3104   182506.0   200554.0   295597.0   335921.0   284352.0
# 3177    23904.0    25950.0    33075.0    35600.0    27816.0
#
# [51 rows x 23 columns]

# %% [markdown]
# Those are rows about States. I will keep the counties:

# %%
snapBenUSCounties=snapBen[snapBen['CountyFIPScode']!=0]

# %%
# checking data types:
snapBenUSCounties.dtypes
# Out:
# StateFIPScode       int64
# CountyFIPScode      int64
# Name               object
# July2013          float64
# July2012          float64
# July2011          float64
# July2010          float64
# July2009          float64
# July2008          float64
# July2007          float64
# July2006          float64
# July2005          float64
# July2004          float64
# July2003          float64
# July2002          float64
# July2001          float64
# July2000          float64
# July1999          float64
# July1998          float64
# July1997          float64
# July1995          float64
# July1993          float64
# July1989          float64
# dtype: object

# %% [markdown]
# The counties tell you to what State they belong, so we could use that to create a new column. Let's see a simple example on how to get information from a text:

# %%
# using split,a function for strings:
'Autauga County, AL'.split(', ') # notice the space after the comma
# you get a list:
# Out:
# ['Autauga County', 'AL']

# %% [markdown]
# The **split**, in this case, returns the state in the second position of the list (index=1), then:

# %%
# saving every second element for each element in the column:
states=[element.split(', ')[1] for element in snapBenUSCounties.Name]

# make that list a new column
snapBenUSCounties=snapBenUSCounties.assign(StateName=states)

# checking:
snapBenUSCounties
# Out:
#       StateFIPScode  CountyFIPScode                    Name  July2013  \
# 1                 1               1      Autauga County, AL    8055.0
# 2                 1               3      Baldwin County, AL   24402.0
# 3                 1               5      Barbour County, AL    6740.0
# 4                 1               7         Bibb County, AL    4175.0
# 5                 1               9       Blount County, AL    9037.0
# 6                 1              11      Bullock County, AL    2966.0
# 7                 1              13       Butler County, AL    5451.0
# 8                 1              15      Calhoun County, AL   25918.0
# 9                 1              17     Chambers County, AL    7624.0
# 10                1              19     Cherokee County, AL    5434.0
# 11                1              21      Chilton County, AL    9205.0
# 12                1              23      Choctaw County, AL    3519.0
# 13                1              25       Clarke County, AL    6970.0
# 14                1              27         Clay County, AL    2319.0
# 15                1              29     Cleburne County, AL    2805.0
# 16                1              31       Coffee County, AL    7215.0
# 17                1              33      Colbert County, AL    9869.0
# 18                1              35      Conecuh County, AL    3914.0
# 19                1              37        Coosa County, AL    1978.0
# 20                1              39    Covington County, AL    8074.0
# 21                1              41     Crenshaw County, AL    2997.0
# 22                1              43      Cullman County, AL   12811.0
# 23                1              45         Dale County, AL   10858.0
# 24                1              47       Dallas County, AL   17240.0
# 25                1              49       DeKalb County, AL   15364.0
# 26                1              51       Elmore County, AL   12839.0
# 27                1              53     Escambia County, AL   10047.0
# 3186     394.0     286.0         WY
# 3187     439.0     246.0         WY
# 3188    5884.0    4692.0         WY
# 3189     562.0     442.0         WY
# 3190    5564.0    3821.0         WY
# 3191     248.0     191.0         WY
# 3192    2488.0    1388.0         WY
# 3193     644.0     517.0         WY
# 3194    1823.0    1162.0         WY
# 3195     162.0     123.0         WY
# 3196    2031.0    1736.0         WY
# 3197     159.0      85.0         WY
# 3198    1267.0     856.0         WY
# 3199     743.0     666.0         WY
# 3200     271.0     300.0         WY
#
# [3150 rows x 24 columns]

# %% [markdown]
# The new column was created. We could get rid of the state information from the counties column:

# %%
# just keep county names
counties=[element.split(', ')[0] for element in snapBenUSCounties.Name]
snapBenUSCounties=snapBenUSCounties.assign(Name=counties)

# %%
# quick look:

snapBenUSCounties.head() # last column will be ate the end...
# Out:
#    StateFIPScode  CountyFIPScode            Name  July2013  July2012  \
# 1              1               1  Autauga County    8055.0    8079.0
# 2              1               3  Baldwin County   24402.0   23169.0
# 3              1               5  Barbour County    6740.0    6843.0
# 4              1               7     Bibb County    4175.0    4269.0
# 5              1               9   Blount County    9037.0    9368.0
#
#    July2011  July2010  July2009  July2008  July2007    ...      July2002  \
# 1    8060.0    7593.0    6907.0    5423.0    4686.0    ...        3352.0
# 2   22184.0   20604.0   16545.0   10848.0    8627.0    ...        4945.0
# 3    6465.0    6324.0    6340.0    5672.0    5389.0    ...        4959.0
# 4    4336.0    4152.0    3848.0    2967.0    2577.0    ...        1953.0
# 5    9425.0    8967.0    7283.0    5695.0    4690.0    ...        3066.0
#
#    July2001  July2000  July1999  July1998  July1997  July1995  July1993  \
# 1    3035.0    2814.0    2700.0    2589.0    2771.0    3611.0    4608.0
# 2    4129.0    4178.0    4372.0    4850.0    5201.0    6928.0    8053.0
# 3    4637.0    4415.0    4490.0    4788.0    4947.0    5268.0    5499.0
# 4    1765.0    1685.0    1631.0    1776.0    1999.0    2085.0    2503.0
# 5    2637.0    2436.0    2593.0    2789.0    2926.0    3373.0    3665.0
#
#    July1989  StateName
# 1    3739.0         AL
# 2    5548.0         AL
# 3    5056.0         AL
# 4    2056.0         AL
# 5    2392.0         AL
#
# [5 rows x 24 columns]

# %% [markdown]
# We can have a better column order:

# %%
oldNames=snapBenUSCounties.columns.tolist()
oldNames
# Out:
# ['StateFIPScode',
#  'CountyFIPScode',
#  'Name',
#  'July2013',
#  'July2012',
#  'July2011',
#  'July2010',
#  'July2009',
#  'July2008',
#  'July2007',
#  'July2006',
#  'July2005',
#  'July2004',
#  'July2003',
#  'July2002',
#  'July2001',
#  'July2000',
#  'July1999',
#  'July1998',
#  'July1997',
#  'July1995',
#  'July1993',
#  'July1989',
#  'StateName']

# %%
newNames=[*oldNames[:2],oldNames[-1],*oldNames[2:-1]]
newNames
# Out:
# ['StateFIPScode',
#  'CountyFIPScode',
#  'StateName',
#  'Name',
#  'July2013',
#  'July2012',
#  'July2011',
#  'July2010',
#  'July2009',
#  'July2008',
#  'July2007',
#  'July2006',
#  'July2005',
#  'July2004',
#  'July2003',
#  'July2002',
#  'July2001',
#  'July2000',
#  'July1999',
#  'July1998',
#  'July1997',
#  'July1995',
#  'July1993',
#  'July1989']

# %%
# reordering columns:

snapBenUSCounties=snapBenUSCounties[newNames]
snapBenUSCounties.head()
# Out:
#    StateFIPScode  CountyFIPScode StateName            Name  July2013  \
# 1              1               1        AL  Autauga County    8055.0
# 2              1               3        AL  Baldwin County   24402.0
# 3              1               5        AL  Barbour County    6740.0
# 4              1               7        AL     Bibb County    4175.0
# 5              1               9        AL   Blount County    9037.0
#
#    July2012  July2011  July2010  July2009  July2008    ...     July2003  \
# 1    8079.0    8060.0    7593.0    6907.0    5423.0    ...       3594.0
# 2   23169.0   22184.0   20604.0   16545.0   10848.0    ...       5659.0
# 3    6843.0    6465.0    6324.0    6340.0    5672.0    ...       4981.0
# 4    4269.0    4336.0    4152.0    3848.0    2967.0    ...       2116.0
# 5    9368.0    9425.0    8967.0    7283.0    5695.0    ...       3527.0
#
#    July2002  July2001  July2000  July1999  July1998  July1997  July1995  \
# 1    3352.0    3035.0    2814.0    2700.0    2589.0    2771.0    3611.0
# 2    4945.0    4129.0    4178.0    4372.0    4850.0    5201.0    6928.0
# 3    4959.0    4637.0    4415.0    4490.0    4788.0    4947.0    5268.0
# 4    1953.0    1765.0    1685.0    1631.0    1776.0    1999.0    2085.0
# 5    3066.0    2637.0    2436.0    2593.0    2789.0    2926.0    3373.0
#
#    July1993  July1989
# 1    4608.0    3739.0
# 2    8053.0    5548.0
# 3    5499.0    5056.0
# 4    2503.0    2056.0
# 5    3665.0    2392.0
#
# [5 rows x 24 columns]

# %%
# JUST SAVING...
snapBenUSCounties.to_csv("snapBenUSCounties.csv",index=None)

# %% [markdown]
# ### Case: Multiple data sets

# %%
corruptLink='https://raw.githubusercontent.com/EvansDataScience/data/master/corruption.csv'
econoLink='https://raw.githubusercontent.com/EvansDataScience/data/master/economic.csv'
enviroLink='https://raw.githubusercontent.com/EvansDataScience/data/master/environment.csv'
pressLink='https://raw.githubusercontent.com/EvansDataScience/data/master/pressfreedom.csv'

# %% [markdown]
# * The _corruptlink_ has data about the _Corruption Perception Index_ (CPI) produced by [Transparency International](https://www.transparency.org/).
#
# * The _econoLink_ has data about the _Economic Freedom Index_ (EFI) produced by [Fraser Institute](https://www.fraserinstitute.org).
#
# * The _enviroLink_ has data about the _Environment Performance Index_ (EPI) produced by [Yale University and Columbia University in collaboration with the World Economic Forum](https://epi.envirocenter.yale.edu/).
#
# * The _pressLink_ has data about the _World Press Freedom Index_ (WPFI) produced by [Reporters Without Borders](https://rsf.org/en/world-press-freedom-index).
#
#
# In this case, I want to join them (not concatenate):

# %%
import pandas as pd
corrupt=pd.read_csv(corruptLink,encoding='Latin-1')
econo=pd.read_csv(econoLink,encoding='Latin-1')
enviro=pd.read_csv(enviroLink,encoding='Latin-1')
press=pd.read_csv(pressLink,encoding='Latin-1')

# %% [markdown]
# As each data set has a differing amount of rows (countries), and possibly a different way to name each one, the result will be far from perfect:

# %%
join1=pd.merge(corrupt,econo)
join2=pd.merge(press,enviro)
indexes=pd.merge(join1,join2)

# %% [markdown]
# As always it is good to verify the data types:

# %%
indexes.dtypes
# Out:
# Country             object
# corruptionIndex      int64
# ISO                 object
# scoreEconomy       float64
# scorepress         float64
# presscat            object
# environment        float64
# environmentCat       int64
# dtype: object

# %% [markdown]
# And check descriptives:

# %%
indexes.describe(include='all')
# Out:
#         Country  corruptionIndex  ISO  scoreEconomy  scorepress presscat  \
# count       129       129.000000  129    129.000000  129.000000      129
# unique      129              NaN  129           NaN         NaN        3
# top     Albania              NaN  CHN           NaN         NaN   Medium
# freq          1              NaN    1           NaN         NaN       71
# mean        NaN        45.418605  NaN      6.829457   31.097597      NaN
# std         NaN        19.296898  NaN      0.907765   13.125220      NaN
# min         NaN        14.000000  NaN      2.920000    8.590000      NaN
# 25%         NaN        31.000000  NaN      6.320000   22.660000      NaN
# 50%         NaN        40.000000  NaN      6.920000   29.920000      NaN
# 75%         NaN        58.000000  NaN      7.510000   40.430000      NaN
# max         NaN        90.000000  NaN      8.810000   80.960000      NaN
#
#         environment  environmentCat
# count    129.000000      129.000000
# unique          NaN             NaN
# top             NaN             NaN
# freq            NaN             NaN
# mean      69.393023        0.542636
# std       14.732355        0.500121
# min       37.100000        0.000000
# 25%       59.250000        0.000000
# 50%       70.840000        1.000000
# 75%       81.260000        1.000000
# max       90.680000        1.000000

# %%
indexes.head()
# Out:
#        Country  corruptionIndex  ISO  scoreEconomy  scorepress presscat  \
# 0  New Zealand               90  NZL          8.48       10.01     High
# 1      Denmark               90  DNK          7.77        8.89     High
# 2      Finland               89  FIN          7.75        8.59     High
# 3       Sweden               88  SWE          7.65       12.33     High
# 4  Switzerland               86  CHE          8.44       11.76     High
#
#    environment  environmentCat
# 0        88.00               1
# 1        89.21               1
# 2        90.68               1
# 3        90.43               1
# 4        86.93               1

# %% [markdown]
# There is some formatting needed:

# %% [markdown]
# Let's order it:

# %%
oldCols=indexes.columns.tolist()
oldCols
# Out:
# ['Country',
#  'corruptionIndex',
#  'ISO',
#  'scoreEconomy',
#  'scorepress',
#  'presscat',
#  'environment',
#  'environmentCat']

# %% [markdown]
# When we do not have slices, there is extra work:

# %%
numericIndex=[oldCols[i] for i in [1,3,4,6]]
numericIndex
# Out:
# ['corruptionIndex', 'scoreEconomy', 'scorepress', 'environment']

# %%
newValues=[oldCols[0],oldCols[2],*numericIndex,oldCols[5],oldCols[7]]
newValues
# Out:
# ['Country',
#  'ISO',
#  'corruptionIndex',
#  'scoreEconomy',
#  'scorepress',
#  'environment',
#  'presscat',
#  'environmentCat']

# %% [markdown]
# Then, the new order will be:

# %%
indexes=indexes[newValues]
indexes.head()
# Out:
#        Country  ISO  corruptionIndex  scoreEconomy  scorepress  environment  \
# 0  New Zealand  NZL               90          8.48       10.01        88.00
# 1      Denmark  DNK               90          7.77        8.89        89.21
# 2      Finland  FIN               89          7.75        8.59        90.68
# 3       Sweden  SWE               88          7.65       12.33        90.43
# 4  Switzerland  CHE               86          8.44       11.76        86.93
#
#   presscat  environmentCat
# 0     High               1
# 1     High               1
# 2     High               1
# 3     High               1
# 4     High               1

# %% [markdown]
# There are several numeric values. Let's see a summary:

# %%
indexes.describe()
# Out:
#        corruptionIndex  scoreEconomy  scorepress  environment  environmentCat
# count       129.000000    129.000000  129.000000   129.000000      129.000000
# mean         45.418605      6.829457   31.097597    69.393023        0.542636
# std          19.296898      0.907765   13.125220    14.732355        0.500121
# min          14.000000      2.920000    8.590000    37.100000        0.000000
# 25%          31.000000      6.320000   22.660000    59.250000        0.000000
# 50%          40.000000      6.920000   29.920000    70.840000        1.000000
# 75%          58.000000      7.510000   40.430000    81.260000        1.000000
# max          90.000000      8.810000   80.960000    90.680000        1.000000

# %% [markdown]
# It is important to find some monotony issues in these values:

# %%
% matplotlib inline
import matplotlib.pyplot as plt
pd.plotting.scatter_matrix(indexes.iloc[:,2:6])
plt.show()
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# Score press is negatively correlated to the rest. That means that the score for that column needs to be reversed:

# %%
# creating reversing function:
def reverse(aColumn):
    return max(aColumn) - aColumn + min(aColumn)

# %%
# reversing using function:
indexes.scorepress=reverse(indexes.scorepress)

# %% [markdown]
# We should see a different result:

# %%
pd.plotting.scatter_matrix(indexes.iloc[:,2:6])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-163-d34484bac44b> in <module>
#       1 pd.plotting.scatter_matrix(indexes.iloc[:,2:6])
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# The variable _presscat_ needs to be an ordinal factor.

# %%
indexes['presscat'].value_counts()
# Out:
# Medium    71
# High      35
# Low       23
# Name: presscat, dtype: int64

# %%
indexes['presscat'].replace({'Medium':2, "High":3, "Low":1},inplace=True)

# %%
indexes['presscat'].value_counts(sort=False)
# Out:
# 1    23
# 2    71
# 3    35
# Name: presscat, dtype: int64

# %% [markdown]
# The numbers will help R users when they set it as an ordinal. You can convert them to ordinal, but that information will be lost in R.

# %%
indexes.head()
# Out:
#        Country  ISO  corruptionIndex  scoreEconomy  scorepress  environment  \
# 0  New Zealand  NZL               90          8.48       79.54        88.00
# 1      Denmark  DNK               90          7.77       80.66        89.21
# 2      Finland  FIN               89          7.75       80.96        90.68
# 3       Sweden  SWE               88          7.65       77.22        90.43
# 4  Switzerland  CHE               86          8.44       77.79        86.93
#
#    presscat  environmentCat
# 0         3               1
# 1         3               1
# 2         3               1
# 3         3               1
# 4         3               1

# %% [markdown]
# We are proposing that the categories coded as numbers follow an asceding format, then let's check if _environmentCat_ should be changed:

# %%
indexes['environmentCat'].value_counts()
# Out:
# 1    70
# 0    59
# Name: environmentCat, dtype: int64

# %% [markdown]
# As there is no need for that, just save the file:

# %%
# indexes.to_csv("indexes.csv",index=None)

# %% [markdown]
# ____
#
# * [Go to page beginning](#beginning)
# * [Go to REPO in Github](https://github.com/EvansDataScience/ComputationalThinking_Gov_2)
# * [Go to Course schedule](https://evansdatascience.github.io/GovernanceAnalytics/)
